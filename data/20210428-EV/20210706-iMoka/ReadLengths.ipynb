# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# Adjust plot size
#options(repr.plot.width=16, repr.plot.height=6)

# For some reason, if this is in the same cell as the import command, it doesn't work.
plt.rcParams["figure.figsize"] = [18.0,10.0]

# %%
df=pd.read_csv("merged.all.all.csv",index_col=['length'])

# %%
df.plot(title="All reads", legend=False)
plt.show()

# %%
df.median(axis=1).plot(title="Median of all reads")
plt.show()

# %%
df=pd.read_csv("merged.all.top20kmers.csv",index_col=['length'])

# %%
df.plot(title="All reads including one of the top 20 kmers",legend=False)
plt.show()

# %%
df.median(axis=1).plot(title="Median of all reads including one of the top 20 kmers")
plt.show()

# %%
df=pd.read_csv("merged.all.top10kmers.csv",index_col=['length'])

# %%
df.plot(title="All reads including one of the top 10 kmers",legend=False)
plt.show()

# %%
df.median(axis=1).plot(title="Median of all reads including one of the top 10 kmers")
plt.show()

# %%
df=pd.read_csv("merged.all.top5kmers.csv",index_col=['length'])

# %%
df.plot(title="All reads including one of the top 5 kmers",legend=False)
plt.show()

# %%
df.median(axis=1).plot(title="Median of all reads including one of the top 5 kmers")
plt.show()

# %%
df=pd.read_csv("merged.all.num5kmer.csv",index_col=['length'])

# %%
df.plot(title="All reads including the 5th top kmer",legend=False)
plt.show()

# %%
df.median(axis=1).plot(title="Median of all reads including the 5th top kmer")
plt.show()

# %%
df=pd.read_csv("merged.all.num4kmer.csv",index_col=['length'])

# %%
df.plot(title="All reads including the 4th top kmer",legend=False)
plt.show()

# %%
df.median(axis=1).plot(title="Median of all reads including the 4th top kmer")
plt.show()

# %%
df=pd.read_csv("merged.all.num3kmer.csv",index_col=['length'])

# %%
df.plot(title="All reads including the 3rd top kmer",legend=False)
plt.show()

# %%
df.median(axis=1).plot(title="Median of all reads including the 3rd top kmer")
plt.show()

# %%
df=pd.read_csv("merged.all.num2kmer.csv",index_col=['length'])

# %%
df.plot(title="All reads including the 2nd top kmer",legend=False)
plt.show()

# %%
df.median(axis=1).plot(title="Median of all reads including the 2nd top kmer")
plt.show()

# %%
df=pd.read_csv("merged.all.num1kmer.csv",index_col=['length'])

# %%
df.plot(title="All reads including the top kmer",legend=False)
plt.show()

# %%
df.median(axis=1).plot(title="Median of all reads including the top kmer")
plt.show()

# %%
df=pd.read_csv("merged.lte30.all.csv",index_col=['length'])

# %%
df.plot(title="Reads LTE 30bp",legend=False)
plt.show()

# %%
df.median(axis=1).plot(title="Median of all reads LTE 30bp")
plt.show()

# %%
df=pd.read_csv("merged.lte30.top20kmers.csv",index_col=['length'])

# %%
df.plot(title="Reads LTE 30bp including one of the top 20 kmers",legend=False)
plt.show()

# %%
df.median(axis=1).plot(title="Median of all reads LTE 30bp including one of the top 20 kmers")
plt.show()

# %%
df=pd.read_csv("merged.lte30.top10kmers.csv",index_col=['length'])

# %%
df.plot(title="Reads LTE 30bp including one of the top 10 kmers",legend=False)
plt.show()

# %%
df.median(axis=1).plot(title="Median of all reads LTE 30bp including one of the top 10 kmers")
plt.show()

# %%
df=pd.read_csv("merged.lte30.top5kmers.csv",index_col=['length'])

# %%
df.plot(title="Reads LTE 30bp including one of the top 5 kmers",legend=False)
plt.show()

# %%
df.median(axis=1).plot(title="Median of all reads LTE 30bp including one of the top 5 kmers")
plt.show()

# %%
df=pd.read_csv("merged.lte30.num5kmer.csv",index_col=['length'])

# %%
df.plot(title="Reads LTE 30bp including the 5th top kmer",legend=False)
plt.show()

# %%
df.median(axis=1).plot(title="Median of all reads LTE 30bp including the 5th top kmer")
plt.show()

# %%
df=pd.read_csv("merged.lte30.num4kmer.csv",index_col=['length'])

# %%
df.plot(title="Reads LTE 30bp including the 4th top kmer",legend=False)
plt.show()

# %%
df.median(axis=1).plot(title="Median of all reads LTE 30bp including the 4th top kmer")
plt.show()

# %%
df=pd.read_csv("merged.lte30.num3kmer.csv",index_col=['length'])

# %%
df.plot(title="Reads LTE 30bp including the 3rd top kmer",legend=False)
plt.show()

# %%
df.median(axis=1).plot(title="Median of all reads LTE 30bp including the 3rd top kmer")
plt.show()

# %%
df=pd.read_csv("merged.lte30.num2kmer.csv",index_col=['length'])

# %%
df.plot(title="Reads LTE 30bp including the 2nd top kmer",legend=False)
plt.show()

# %%
df.median(axis=1).plot(title="Median of all reads LTE 30bp including the 2nd top kmer")
plt.show()

# %%
df=pd.read_csv("merged.lte30.num1kmer.csv",index_col=['length'])

# %%
df.plot(title="Reads LTE 30bp including the top kmer",legend=False)
plt.show()

# %%
df.median(axis=1).plot(title="Median of all reads LTE 30bp including the top kmer")
plt.show()

# %% [raw]
# sort -k2n output_fi.tsv | tail -20 | cut -f1 > output_fi.top20kmers.fw
# sort -k2n output_fi.tsv | tail -10 | cut -f1 > output_fi.top10kmers.fw
# sort -k2n output_fi.tsv | tail -5 | cut -f1 > output_fi.top5kmers.fw
# sort -k2nr output_fi.tsv | head -1 | cut -f1 > output_fi.num1kmer.fw
# sort -k2nr output_fi.tsv | head -2 | tail -1 | cut -f1 > output_fi.num2kmer.fw
# sort -k2nr output_fi.tsv | head -3 | tail -1 | cut -f1 > output_fi.num3kmer.fw
# sort -k2nr output_fi.tsv | head -4 | tail -1 | cut -f1 > output_fi.num4kmer.fw
# sort -k2nr output_fi.tsv | head -5 | tail -1 | cut -f1 > output_fi.num5kmer.fw
#
#
# cat output_fi.top20kmers.fw | tr "[ATGCatgc]" "[TACGtacg]" | rev > output_fi.top20kmers.rc
#
# cat output_fi.top20kmers.fw output_fi.top20kmers.rc > output_fi.top20kmers
#
# zcat /francislab/data1/working/20210428-EV/20210706-iMoka/raw.cutadapt2.lte30/SFHH005a.fastq.gz | paste - - - -  | cut -f2 | grep -f output_fi.top20kmers | awk '{print length($0)}' | sort -n | uniq -c
#
#
#
# for f in /francislab/data1/working/20210428-EV/20210706-iMoka/raw.cutadapt2.lte30/SFHH005*.fastq.gz ; do
# echo $f
# b=$( basename $f .fastq.gz )
# zcat $f | paste - - - -  | cut -f2 | grep -f output_fi.top20kmers.fw | awk '{print length($0)}' | sort -n | uniq -c > ${b}.lte30.top20kmers.fw
# zcat $f | paste - - - -  | cut -f2 | grep -f output_fi.top10kmers.fw | awk '{print length($0)}' | sort -n | uniq -c > ${b}.lte30.top10kmers.fw
# zcat $f | paste - - - -  | cut -f2 | grep -f output_fi.top5kmers.fw | awk '{print length($0)}' | sort -n | uniq -c > ${b}.lte30.top5kmers.fw
# zcat $f | paste - - - -  | cut -f2 | awk '{print length($0)}' | sort -n | uniq -c > ${b}.lte30.all.fw
# done
#
#
# for f in /francislab/data1/working/20210428-EV/20210706-iMoka/raw.cutadapt2/SFHH005*.fastq.gz ; do
# echo $f
# b=$( basename $f .fastq.gz )
# zcat $f | paste - - - -  | cut -f2 | grep -f output_fi.top20kmers.fw | awk '{print length($0)}' | sort -n | uniq -c > ${b}.all.top20kmers.fw
# zcat $f | paste - - - -  | cut -f2 | grep -f output_fi.top10kmers.fw | awk '{print length($0)}' | sort -n | uniq -c > ${b}.all.top10kmers.fw
# zcat $f | paste - - - -  | cut -f2 | grep -f output_fi.top5kmers.fw | awk '{print length($0)}' | sort -n | uniq -c > ${b}.all.top5kmers.fw
# zcat $f | paste - - - -  | cut -f2 | awk '{print length($0)}' | sort -n | uniq -c > ${b}.all.all.fw
# done
#
#
#
#
#
#
# for i in $( seq 5 ) ; do
# echo $i
#
# for f in /francislab/data1/working/20210428-EV/20210706-iMoka/raw.cutadapt2.lte30/SFHH005*.fastq.gz ; do
# echo $f
# b=$( basename $f .fastq.gz )
# zcat $f | paste - - - -  | cut -f2 | grep -f output_fi.num${i}kmer.fw | awk '{print length($0)}' | sort -n | uniq -c > ${b}.lte30.num${i}kmer.fw
# done
#
# for f in /francislab/data1/working/20210428-EV/20210706-iMoka/raw.cutadapt2/SFHH005*.fastq.gz ; do
# echo $f
# b=$( basename $f .fastq.gz )
# zcat $f | paste - - - -  | cut -f2 | grep -f output_fi.num${i}kmer.fw | awk '{print length($0)}' | sort -n | uniq -c > ${b}.all.num${i}kmer.fw
# done
#
# done
#
#
#
# for a in all lte30 ; do
# for b in all top20kmers top10kmers top5kmers num1kmer num2kmer num3kmer num4kmer num5kmer ; do
# python3 ~/.local/bin/merge_uniq-c.py --int --seqint --output merged.${a}.${b}.csv SFHH005*.${a}.${b}.fw
# done ; done

# %% [markdown]
# # Align the top 20 kmers

# %% [raw]
# sort -k2n output_fi.tsv | tail -20
#
# TTGAAGGGGGCTTCT	33.689118784221066
# CCAAATAGGGCAGGC	35.46859707708299
# GGGGGAACGGCTGTA	36.269653853173644
# TGCAATCTACTCGCG	37.847783248447385
# ACAGAGCCAGACTCT	37.94597011473864
# GGGAAAATCGTAACT	37.95503742892041
# GGGTGAAGTGGTTGC	38.893838722866626
# GTAGAGCACTGGATG	39.370532979946304
# GGTTTATGAATTTAT	40.244032027386844
# GAATTGACGGGGGCC	40.733789753881744
# GGGGATCGCGGAAGG	42.542584211388764
# GATGCGTGCATTTAT	44.9304394114175
# GCTAACTTCCGGTGT	52.55684358960925
# TAGCAGTGGGGAATT	54.39930403677019
# CTGACTCGAAATCAG	56.13259472086436
# GCGTGCTCAGGCGGT	56.23214959749874
# TGCGCGAGATGAGTA	61.79564149848666
# CAGAGCGAGACCCTG	64.2053617929187
# GAGCCCCATCAGCCA	78.55838352084986
# GTGCGAATGCTTACA	99.93463415301333
#
# awk '{print ">"$0;print $0}' output_fi.top20kmers.fw > output_fi.top20kmers.fw.fa

# %% [markdown]
# # Alignments to hg38

# %% [raw]
# bowtie2 --xeq --threads 16 --very-sensitive -x /francislab/data1/refs/sources/hgdownload.cse.ucsc.edu/goldenPath/hg38/bigZips/latest/hg38.chrXYM_alts -f output_fi.top20kmers.fw.fa 2> /dev/null | awk '(!/^@/){print $1,$3,$4}'
#
# TTGAAGGGGGCTTCT chr20 33228769
# CCAAATAGGGCAGGC chr1 96619601
# GGGGGAACGGCTGTA chr16 24385725
# TGCAATCTACTCGCG chr2 103977089
# ACAGAGCCAGACTCT chr11 47557242
# GGGAAAATCGTAACT chr17 80367525
# GGGTGAAGTGGTTGC chr6_GL000254v2_alt 4599469
# GTAGAGCACTGGATG chr22 16786580
# GGTTTATGAATTTAT chr3 17169469
# GAATTGACGGGGGCC chr2 235959642
# GGGGATCGCGGAAGG chr16 71424383
# GATGCGTGCATTTAT chr7 62108083
# GCTAACTTCCGGTGT chrX 64171532
# TAGCAGTGGGGAATT chr7 18366094
# CTGACTCGAAATCAG chr14 71883021
# GCGTGCTCAGGCGGT chr9 9806684
# TGCGCGAGATGAGTA chr21 43582426
# CAGAGCGAGACCCTG chr16 81896559
# GAGCCCCATCAGCCA chr20 61795333
# GTGCGAATGCTTACA chr16 83783126

# %% [markdown]
# # Align to miRNA

# %% [raw]
# bowtie2 --xeq --threads 16 --very-sensitive -x /francislab/data1/refs/sources/mirbase.org/pub/mirbase/CURRENT/human_mirna -f output_fi.top20kmers.fw.fa 2> /dev/null | awk '(!/^@/){print $1,$3,$4}'
#
# TTGAAGGGGGCTTCT * 0
# CCAAATAGGGCAGGC * 0
# GGGGGAACGGCTGTA * 0
# TGCAATCTACTCGCG * 0
# ACAGAGCCAGACTCT hsa-mir-8086-hairpin 56
# GGGAAAATCGTAACT * 0
# GGGTGAAGTGGTTGC * 0
# GTAGAGCACTGGATG * 0
# GGTTTATGAATTTAT * 0
# GAATTGACGGGGGCC * 0
# GGGGATCGCGGAAGG * 0
# GATGCGTGCATTTAT * 0
# GCTAACTTCCGGTGT * 0
# TAGCAGTGGGGAATT * 0
# CTGACTCGAAATCAG * 0
# GCGTGCTCAGGCGGT * 0
# TGCGCGAGATGAGTA * 0
# CAGAGCGAGACCCTG * 0
# GAGCCCCATCAGCCA * 0
# GTGCGAATGCTTACA * 0

# %% [markdown]
# # Align to human RNA

# %% [raw]
# bowtie2 --xeq --threads 16 --very-sensitive -x /francislab/data1/refs/refseq/mRNA_Prot-20210528/human.rna -f output_fi.top20kmers.fw.fa 2> /dev/null | awk '(!/^@/){print $1,$3,$4}'
#
# TTGAAGGGGGCTTCT XM_017009102.2 11820
# CCAAATAGGGCAGGC XM_024449371.1 896
# GGGGGAACGGCTGTA NM_001040118.3 2677
# TGCAATCTACTCGCG NM_199511.3 4977
# ACAGAGCCAGACTCT XM_011517736.3 1805
# GGGAAAATCGTAACT NM_001001670.3 3896
# GGGTGAAGTGGTTGC XM_017010251.2 4746
# GTAGAGCACTGGATG NM_001243812.2 7934
# GGTTTATGAATTTAT XM_011542948.2 1481
# GAATTGACGGGGGCC NM_001324029.3 1701
# GGGGATCGCGGAAGG XM_005268625.3 3910
# GATGCGTGCATTTAT NR_046235.3 3862
# GCTAACTTCCGGTGT NR_038259.1 4009
# TAGCAGTGGGGAATT NM_015990.5 5288
# CTGACTCGAAATCAG XR_001751149.1 3473
# GCGTGCTCAGGCGGT XR_001739967.1 157
# TGCGCGAGATGAGTA XM_006721423.3 457
# CAGAGCGAGACCCTG XM_024451883.1 2482
# GAGCCCCATCAGCCA NM_001390843.1 1098
# GTGCGAATGCTTACA XM_011544285.3 2245

# %% [markdown]
# # Extract the transcript names

# %% [raw]
# bowtie2 --xeq --threads 16 --very-sensitive -x /francislab/data1/refs/refseq/mRNA_Prot-20210528/human.rna -f output_fi.top20kmers.fw.fa 2> /dev/null | awk '(!/^@/){print $3}' | awk -F. '{print $1}' | sort > human.rna.transcripts
#
# cat human.rna.transcripts
# NM_001001670
# NM_001040118
# NM_001243812
# NM_001324029
# NM_001390843
# NM_015990
# NM_199511
# NR_038259
# NR_046235
# XM_005268625
# XM_006721423
# XM_011517736
# XM_011542948
# XM_011544285
# XM_017009102
# XM_017010251
# XM_024449371
# XM_024451883
# XR_001739967
# XR_001751149

# %% [markdown]
# # Get the Gene names that contain the found transcripts

# %% [raw]
# grep -f human.rna.transcripts /francislab/data1/refs/sources/hgdownload.cse.ucsc.edu/goldenPath/hg38/bigZips/genes/hg38.ncbiRefSeq.transcript_gene.tsv
#
# NM_001001670.3	SPATA31D1
# NM_001040118.2	ARAP1
# NM_001243812.2	CACNA1B
# NM_001324029.2	SEMA4B
# NM_001390843
# NM_015990.4	KLHL5
# NM_199511.2	CCDC80
# NR_038259.1	TPTE2P5
# NR_046235.3	RNA45SN5
# XM_005268625.3	AGAP2
# XM_006721423.3	CHD3
# XM_011517736.3	TRMT10B
# XM_011542948.2	MMP27
# XM_011544285.3	TRIM11
# XM_017009102.2	TMEM161B
# XM_017010251.2	COL11A2
# XM_024449371.1	ENOX1
# XM_024451883.1	EFCAB8
# XR_001739967.1	LOC105373960
# XR_001751149.1	FAN1
