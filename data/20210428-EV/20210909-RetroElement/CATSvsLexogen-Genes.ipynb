# %%
import pandas as pd
pd.__version__
# Out:
# '1.3.2'

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.4.2'

# %%
import matplotlib.pyplot as plt

# %%
# Adjust plot size
#options(repr.plot.width=16, repr.plot.height=6)

# For some reason, if this is in the same cell as the import command, it doesn't work.
#plt.rcParams["figure.figsize"] = [18.0,8.0]

# %%
import seaborn as sns
sns.__version__
# Out:
# '0.11.2'

# %%
df = pd.read_csv('feature_counts.5.cutadapt2.genes.summary.tsv',sep="\t")
sum=df.sum().to_frame().T
sum['Status']='sum'
sum
df=pd.concat([df,sum],axis='index')
del(sum)
df.set_index('Status',inplace=True)
df=df.T
df.drop(['Unassigned_Read_Type','Unassigned_Singleton','Unassigned_MappingQuality','Unassigned_Chimera',
    'Unassigned_FragmentLength','Unassigned_Duplicate','Unassigned_MultiMapping','Unassigned_Secondary',
    'Unassigned_NonSplit','Unassigned_Overlapping_Length',
    'Unassigned_Unmapped','Unassigned_NoFeatures','Unassigned_Ambiguity'],axis='columns',inplace=True)
#df['assigned per million']=1e6*df['Assigned']/df['sum']
cats=df
del(df)
cats
# Out:
# Status    Assigned       sum
# SFHH005aa   110033   1384146
# SFHH005ab   319399   1362728
# SFHH005ac   540765   2031764
# SFHH005a    568050   3156527
# SFHH005ad   141040   1198332
# SFHH005ae   220254   1805765
# SFHH005af   346532   2252796
# SFHH005ag   105856   1298583
# SFHH005ah   308075   1208514
# SFHH005ai   159895   1251601
# SFHH005aj  1514052   3361571
# SFHH005ak   111228   1006820
# SFHH005al   345276   1266917
# SFHH005am   535621   2171610
# SFHH005an   112170    651667
# SFHH005ao    79195    968716
# SFHH005ap   110547    989509
# SFHH005aq    76301    361097
# SFHH005b     30929   2540660
# SFHH005c    412675   3148141
# SFHH005d     61310   2165837
# SFHH005e    113288   3120986
# SFHH005f     87912   2173480
# SFHH005g   1980963   4938019
# SFHH005h    139216  10068474
# SFHH005i    540896   3177085
# SFHH005j     40355   2567706
# SFHH005k    203063   1127360
# SFHH005l     39605   1301876
# SFHH005m     94932   1284059
# SFHH005n     90081   2344557
# SFHH005o     45473    732781
# SFHH005p    185453   1490268
# SFHH005q     82948   1210691
# SFHH005r     57341    969936
# SFHH005s     85186    729603
# SFHH005t    451209   1733625
# SFHH005u    125675   1137757
# SFHH005w    420468   1939620
# SFHH005x     91262   1065544
# SFHH005y    680507   2050034
# SFHH005z    553511   1639493

# %%
df = pd.read_csv('feature_counts.6.cutadapt2.genes.summary.tsv',sep="\t")
sum=df.sum().to_frame().T
sum['Status']='sum'
sum
df=pd.concat([df,sum],axis='index')
del(sum)
df.set_index('Status',inplace=True)
df=df.T
df.drop(['Unassigned_Read_Type','Unassigned_Singleton','Unassigned_MappingQuality','Unassigned_Chimera',
    'Unassigned_FragmentLength','Unassigned_Duplicate','Unassigned_MultiMapping','Unassigned_Secondary',
    'Unassigned_NonSplit','Unassigned_Overlapping_Length',
    'Unassigned_Unmapped','Unassigned_NoFeatures','Unassigned_Ambiguity'],axis='columns',inplace=True)
#df['assigned per million']=1e6*df['Assigned']/df['sum']
lex=df
del(df)
lex
# Out:
# SFHH006n      6051  4186488          1445.364229  Lexogen
# SFHH006o      2987  3094398           965.292765  Lexogen
# SFHH006p      2693  1817935          1481.351093  Lexogen
# SFHH006q      2490  1128000          2207.446809  Lexogen
# SFHH006r      2139  1615695          1323.888481  Lexogen
# SFHH006s      2787  2045126          1362.752222  Lexogen
# SFHH006t      4431  2131823          2078.502765  Lexogen
# SFHH006u      1552  3808940           407.462444  Lexogen
# SFHH006w      1621   486347          3333.011204  Lexogen
# SFHH006x      9608  3679289            2611.3741  Lexogen
# SFHH006y     17659  3653219          4833.819161  Lexogen
# SFHH006z     20028  4852978          4126.950503  Lexogen

# %%
#cats=cats_LTR+cats_Retroposon
cats['assigned per million']=1e6*cats['Assigned']/cats['sum']
cats['library']='CATS'
#cats.drop(['SFHH005ag','SFHH005ar','SFHH005k','SFHH005v'],inplace=True,axis='index')
cats.drop(['SFHH005ag','SFHH005k'],inplace=True,axis='index')
cats
# Out:
# Status    Assigned       sum assigned per million library
# SFHH005aa   110033   1384146          79495.22666    CATS
# SFHH005ab   319399   1362728        234382.063038    CATS
# SFHH005ac   540765   2031764        266155.419626    CATS
# SFHH005a    568050   3156527        179960.443868    CATS
# SFHH005ad   141040   1198332        117696.932069    CATS
# SFHH005ae   220254   1805765        121972.681938    CATS
# SFHH005af   346532   2252796        153823.071419    CATS
# SFHH005ah   308075   1208514        254920.505679    CATS
# SFHH005ai   159895   1251601        127752.374758    CATS
# SFHH005aj  1514052   3361571        450400.125418    CATS
# SFHH005ak   111228   1006820        110474.563477    CATS
# SFHH005al   345276   1266917         272532.45477    CATS
# SFHH005am   535621   2171610        246646.957787    CATS
# SFHH005an   112170    651667        172127.789193    CATS
# SFHH005ao    79195    968716          81752.54667    CATS
# SFHH005ap   110547    989509        111719.044496    CATS
# SFHH005aq    76301    361097        211303.334007    CATS
# SFHH005b     30929   2540660         12173.608432    CATS
# SFHH005c    412675   3148141        131085.297641    CATS
# SFHH005d     61310   2165837         28307.762773    CATS
# SFHH005e    113288   3120986         36298.785063    CATS
# SFHH005f     87912   2173480         40447.577157    CATS
# SFHH005g   1980963   4938019         401165.52812    CATS
# SFHH005h    139216  10068474         13826.921537    CATS
# SFHH005i    540896   3177085        170249.143476    CATS
# SFHH005j     40355   2567706         15716.363166    CATS
# SFHH005l     39605   1301876         30421.484074    CATS
# SFHH005m     94932   1284059          73931.18229    CATS
# SFHH005n     90081   2344557         38421.330767    CATS
# SFHH005o     45473    732781         62055.375344    CATS
# SFHH005p    185453   1490268        124442.717686    CATS
# SFHH005q     82948   1210691         68512.940131    CATS
# SFHH005r     57341    969936         59118.333581    CATS
# SFHH005s     85186    729603        116756.647108    CATS
# SFHH005t    451209   1733625        260269.089336    CATS
# SFHH005u    125675   1137757        110458.560132    CATS
# SFHH005w    420468   1939620        216778.544251    CATS
# SFHH005x     91262   1065544         85648.269804    CATS
# SFHH005y    680507   2050034        331949.128649    CATS
# SFHH005z    553511   1639493        337611.078547    CATS

# %% [markdown]
# control
#
# SFHH005k | SFHH005ag | SFHH006k | SFHH006ag

# %%
#df.plot( y='assigned per million')

# %%
#meta=pd.read_csv('metadata.csv')
##meta.drop(['Rand 2 Batch_order'],inplace=True,axis='columns')
###meta.drop([Lexogen Sequencing ID'],inplace=True,axis='columns')
###meta.drop(meta[meta['Diagnosis'].str.contains('blank')].index,inplace=True)
###meta.set_index('D-plex Sequencing ID',inplace=True)
#meta.drop(['Diagnosis'],inplace=True,axis='columns')
#meta.set_index('Rand 2 Batch_order',inplace=True)
#meta

# %%
#df=meta.merge(cats,left_on='D-plex Sequencing ID',right_index=True)
#df
#df=df.merge(meta,left_index=True,right_index=True)
#df

# %%
# Drop *ar, *ag, *v, *k

# %%
df=pd.concat([cats,lex])
df
# Out:
# Status    Assigned      sum assigned per million  library
# SFHH005aa   110033  1384146          79495.22666     CATS
# SFHH005ab   319399  1362728        234382.063038     CATS
# SFHH005ac   540765  2031764        266155.419626     CATS
# SFHH005a    568050  3156527        179960.443868     CATS
# SFHH005ad   141040  1198332        117696.932069     CATS
# ...            ...      ...                  ...      ...
# SFHH006u      1552  3808940           407.462444  Lexogen
# SFHH006w      1621   486347          3333.011204  Lexogen
# SFHH006x      9608  3679289            2611.3741  Lexogen
# SFHH006y     17659  3653219          4833.819161  Lexogen
# SFHH006z     20028  4852978          4126.950503  Lexogen
#
# [80 rows x 4 columns]

# %%
df.dtypes
# Out:
# Status
# Assigned                object
# sum                     object
# assigned per million    object
# library                 object
# dtype: object

# %%
df['assigned per million']=df['assigned per million'].astype(float)

# %%
df.dtypes
# Out:
# Status
# Assigned                 object
# sum                      object
# assigned per million    float64
# library                  object
# dtype: object

# %%
ax=df.boxplot(column='assigned per million',by=['library'])
ax.set_xlabel("Preparation Library")
ax.set_ylabel("Assigned per million")
plt.title('')
plt.suptitle('')
plt.show()

# %%
ax=sns.boxplot(x="library", y="assigned per million", data=df)
ax.set_xlabel("Preparation Library")
ax.set_ylabel("Assigned per million")
plt.show()

# %%
ax=sns.swarmplot(x="library", y="assigned per million", data=df,size=5,
    edgecolor='black',linewidth=1,linestyle='-')
ax.set_xlabel("Preparation Library")
ax.set_ylabel("Assigned per million")
plt.show()
# Out:
# /Users/jake/Library/Python/3.8/lib/python/site-packages/seaborn/categorical.py:1296: UserWarning: 37.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
ax=sns.boxplot(x="library", y="assigned per million", data=df)
ax=sns.swarmplot(x="library", y="assigned per million", data=df,size=5,
    edgecolor='black',linewidth=1,linestyle='-')
ax.set_xlabel("Preparation Library")
ax.set_ylabel("Assigned per million")
plt.show()
# Out:
# /Users/jake/Library/Python/3.8/lib/python/site-packages/seaborn/categorical.py:1296: UserWarning: 37.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
ax=sns.stripplot(x="library", y="assigned per million", data=df,size=5,
    edgecolor='black',linewidth=1,linestyle='-')
ax.set_xlabel("Preparation Library")
ax.set_ylabel("Assigned per million")
plt.show()

# %%
ax=sns.violinplot(x="library", y="assigned per million", data=df)
ax.set_xlabel("Preparation Library")
ax.set_ylabel("Assigned per million")
plt.show()
