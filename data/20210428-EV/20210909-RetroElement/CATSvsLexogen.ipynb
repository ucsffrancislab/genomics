# %%
import pandas as pd
pd.__version__
# Out:
# '1.3.2'

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.4.2'

# %%
import matplotlib.pyplot as plt

# %%
# Adjust plot size
#options(repr.plot.width=16, repr.plot.height=6)

# For some reason, if this is in the same cell as the import command, it doesn't work.
#plt.rcParams["figure.figsize"] = [18.0,8.0]

# %%
import seaborn as sns
sns.__version__
# Out:
# '0.11.2'

# %%
df = pd.read_csv('feature_counts.5.cutadapt2.LTR.summary.tsv',sep="\t")
sum=df.sum().to_frame().T
sum['Status']='sum'
sum
df=pd.concat([df,sum],axis='index')
del(sum)
df.set_index('Status',inplace=True)
df=df.T
df.drop(['Unassigned_Read_Type','Unassigned_Singleton','Unassigned_MappingQuality','Unassigned_Chimera',
    'Unassigned_FragmentLength','Unassigned_Duplicate','Unassigned_MultiMapping','Unassigned_Secondary',
    'Unassigned_NonSplit','Unassigned_Overlapping_Length',
    'Unassigned_Unmapped','Unassigned_NoFeatures','Unassigned_Ambiguity'],axis='columns',inplace=True)
#df['assigned per million']=1e6*df['Assigned']/df['sum']
cats_LTR=df
del(df)
cats_LTR
# Out:
# Status    Assigned       sum
# SFHH005aa    17748   1384146
# SFHH005ab    34329   1362728
# SFHH005ac    94633   2031764
# SFHH005a     91725   3156527
# SFHH005ad    21577   1198332
# SFHH005ae    35705   1805765
# SFHH005af    58302   2252796
# SFHH005ag    12794   1298583
# SFHH005ah    42816   1208514
# SFHH005ai    19558   1251601
# SFHH005aj   237910   3361571
# SFHH005ak    13741   1006820
# SFHH005al    45058   1266917
# SFHH005am    82437   2171610
# SFHH005an    16973    651667
# SFHH005ao    11713    968716
# SFHH005ap    16814    989509
# SFHH005aq    10963    361097
# SFHH005b      4659   2540660
# SFHH005c     61127   3148141
# SFHH005d      8661   2165837
# SFHH005e     14116   3120986
# SFHH005f     13360   2173480
# SFHH005g    352652   4938019
# SFHH005h     22165  10068474
# SFHH005i     93698   3177085
# SFHH005j      6350   2567706
# SFHH005k     19262   1127360
# SFHH005l      6322   1301876
# SFHH005m     12374   1284059
# SFHH005n     16002   2344557
# SFHH005o      6795    732781
# SFHH005p     29187   1490268
# SFHH005q     11763   1210691
# SFHH005r      8013    969936
# SFHH005s     12221    729603
# SFHH005t     70906   1733625
# SFHH005u      9184   1137757
# SFHH005w     74985   1939620
# SFHH005x     14257   1065544
# SFHH005y    126956   2050034
# SFHH005z     99016   1639493

# %%
df = pd.read_csv('feature_counts.5.cutadapt2.Retroposon.summary.tsv',sep="\t")
sum=df.sum().to_frame().T
sum['Status']='sum'
sum
df=pd.concat([df,sum],axis='index')
del(sum)
df.set_index('Status',inplace=True)
df=df.T
df.drop(['Unassigned_Read_Type','Unassigned_Singleton','Unassigned_MappingQuality','Unassigned_Chimera',
    'Unassigned_FragmentLength','Unassigned_Duplicate','Unassigned_MultiMapping','Unassigned_Secondary',
    'Unassigned_NonSplit','Unassigned_Overlapping_Length',
    'Unassigned_Unmapped','Unassigned_NoFeatures','Unassigned_Ambiguity'],axis='columns',inplace=True)
#df['assigned per million']=1e6*df['Assigned']/df['sum']
cats_Retroposon=df
del(df)
cats_Retroposon
# Out:
# Status    Assigned       sum
# SFHH005aa      517   1384146
# SFHH005ab      956   1362728
# SFHH005ac     1879   2031764
# SFHH005a      1614   3156527
# SFHH005ad      524   1198332
# SFHH005ae     1650   1805765
# SFHH005af     1133   2252796
# SFHH005ag      726   1298583
# SFHH005ah     1450   1208514
# SFHH005ai      728   1251601
# SFHH005aj     6273   3361571
# SFHH005ak      628   1006820
# SFHH005al     1430   1266917
# SFHH005am     2211   2171610
# SFHH005an      655    651667
# SFHH005ao      353    968716
# SFHH005ap      473    989509
# SFHH005aq      483    361097
# SFHH005b        88   2540660
# SFHH005c      1375   3148141
# SFHH005d       196   2165837
# SFHH005e       347   3120986
# SFHH005f       552   2173480
# SFHH005g      5164   4938019
# SFHH005h       571  10068474
# SFHH005i      1943   3177085
# SFHH005j       148   2567706
# SFHH005k       620   1127360
# SFHH005l       190   1301876
# SFHH005m       495   1284059
# SFHH005n       443   2344557
# SFHH005o       167    732781
# SFHH005p      1373   1490268
# SFHH005q       751   1210691
# SFHH005r       337    969936
# SFHH005s       507    729603
# SFHH005t      2590   1733625
# SFHH005u       169   1137757
# SFHH005w      1673   1939620
# SFHH005x       616   1065544
# SFHH005y      2151   2050034
# SFHH005z      1792   1639493

# %%
df = pd.read_csv('feature_counts.6.cutadapt2.LTR.summary.tsv',sep="\t")
sum=df.sum().to_frame().T
sum['Status']='sum'
sum
df=pd.concat([df,sum],axis='index')
del(sum)
df.set_index('Status',inplace=True)
df=df.T
df.drop(['Unassigned_Read_Type','Unassigned_Singleton','Unassigned_MappingQuality','Unassigned_Chimera',
    'Unassigned_FragmentLength','Unassigned_Duplicate','Unassigned_MultiMapping','Unassigned_Secondary',
    'Unassigned_NonSplit','Unassigned_Overlapping_Length',
    'Unassigned_Unmapped','Unassigned_NoFeatures','Unassigned_Ambiguity'],axis='columns',inplace=True)
#df['assigned per million']=1e6*df['Assigned']/df['sum']
lex_LTR=df
del(df)
lex_LTR
# Out:
# Status    Assigned      sum
# SFHH006aa       65  4524940
# SFHH006ab      637  4304436
# SFHH006ac      724  3257434
# SFHH006a        18   361814
# SFHH006ad      192  3855201
# SFHH006ae      332  4152134
# SFHH006af     1079  5023498
# SFHH006ag       24   703540
# SFHH006ah       17   711448
# SFHH006ai      101  6465973
# SFHH006aj     9224  2747638
# SFHH006ak       53  5364199
# SFHH006al      242  7221383
# SFHH006am      513  3973240
# SFHH006an     2979  3430229
# SFHH006ao      155  2740408
# SFHH006ap       44  4048967
# SFHH006aq     8485  4704132
# SFHH006b        17   398794
# SFHH006c       201   454348
# SFHH006d       278  1385143
# SFHH006e        26   621286
# SFHH006f       147   899472
# SFHH006g      6626  1800164
# SFHH006h        68   573635
# SFHH006i      2828  5121824
# SFHH006j        25   468715
# SFHH006k       360  4743266
# SFHH006l       202  3104046
# SFHH006m       156  2108243
# SFHH006n       223  4186488
# SFHH006o       207  3094398
# SFHH006p       269  1817935
# SFHH006q        51  1128000
# SFHH006r       104  1615695
# SFHH006s        85  2045126
# SFHH006t       561  2131823
# SFHH006u       168  3808940
# SFHH006w        51   486347
# SFHH006x       113  3679289
# SFHH006y      1221  3653219
# SFHH006z      2488  4852978

# %%
df = pd.read_csv('feature_counts.6.cutadapt2.Retroposon.summary.tsv',sep="\t")
sum=df.sum().to_frame().T
sum['Status']='sum'
sum
df=pd.concat([df,sum],axis='index')
del(sum)
df.set_index('Status',inplace=True)
df=df.T
df.drop(['Unassigned_Read_Type','Unassigned_Singleton','Unassigned_MappingQuality','Unassigned_Chimera',
    'Unassigned_FragmentLength','Unassigned_Duplicate','Unassigned_MultiMapping','Unassigned_Secondary',
    'Unassigned_NonSplit','Unassigned_Overlapping_Length',
    'Unassigned_Unmapped','Unassigned_NoFeatures','Unassigned_Ambiguity'],axis='columns',inplace=True)
#df['assigned per million']=1e6*df['Assigned']/df['sum']
lex_Retroposon=df
del(df)
lex_Retroposon
# Out:
# Status    Assigned      sum
# SFHH006aa        9  4524940
# SFHH006ab       11  4304436
# SFHH006ac        8  3257434
# SFHH006a         2   361814
# SFHH006ad       12  3855201
# SFHH006ae        9  4152134
# SFHH006af       20  5023498
# SFHH006ag        1   703540
# SFHH006ah        1   711448
# SFHH006ai       15  6465973
# SFHH006aj       95  2747638
# SFHH006ak       24  5364199
# SFHH006al       22  7221383
# SFHH006am       16  3973240
# SFHH006an       45  3430229
# SFHH006ao       15  2740408
# SFHH006ap        7  4048967
# SFHH006aq      199  4704132
# SFHH006b         0   398794
# SFHH006c         0   454348
# SFHH006d         2  1385143
# SFHH006e         2   621286
# SFHH006f         1   899472
# SFHH006g         2  1800164
# SFHH006h         0   573635
# SFHH006i        19  5121824
# SFHH006j         1   468715
# SFHH006k        14  4743266
# SFHH006l        11  3104046
# SFHH006m         9  2108243
# SFHH006n        14  4186488
# SFHH006o        14  3094398
# SFHH006p         6  1817935
# SFHH006q         6  1128000
# SFHH006r         8  1615695
# SFHH006s         7  2045126
# SFHH006t        14  2131823
# SFHH006u        16  3808940
# SFHH006w         1   486347
# SFHH006x         6  3679289
# SFHH006y        27  3653219
# SFHH006z        17  4852978

# %%
lex=lex_LTR+lex_Retroposon
lex['assigned per million']=1e6*lex['Assigned']/lex['sum']
lex['library']='Lexogen'
lex.drop(['SFHH006ag','SFHH006k'],inplace=True,axis='index')
lex
# Out:
# Status    Assigned       sum assigned per million  library
# SFHH006aa       74   9049880             8.176904  Lexogen
# SFHH006ab      648   8608872            75.271185  Lexogen
# SFHH006ac      732   6514868           112.358378  Lexogen
# SFHH006a        20    723628             27.63851  Lexogen
# SFHH006ad      204   7710402            26.457764  Lexogen
# SFHH006ae      341   8304268            41.063222  Lexogen
# SFHH006af     1099  10046996            109.38593  Lexogen
# SFHH006ah       18   1422896            12.650257  Lexogen
# SFHH006ai      116  12931946             8.970034  Lexogen
# SFHH006aj     9319   5495276          1695.820192  Lexogen
# SFHH006ak       77  10728398             7.177213  Lexogen
# SFHH006al      264  14442766            18.279047  Lexogen
# SFHH006am      529   7946480            66.570356  Lexogen
# SFHH006an     3024   6860458           440.786898  Lexogen
# SFHH006ao      170   5480816            31.017279  Lexogen
# SFHH006ap       51   8097934             6.297903  Lexogen
# SFHH006aq     8684   9408264           923.018317  Lexogen
# SFHH006b        17    797588            21.314263  Lexogen
# SFHH006c       201    908696           221.196088  Lexogen
# SFHH006d       280   2770286           101.072597  Lexogen
# SFHH006e        28   1242572            22.533905  Lexogen
# SFHH006f       148   1798944            82.270488  Lexogen
# SFHH006g      6628   3600328          1840.943381  Lexogen
# SFHH006h        68   1147270            59.271139  Lexogen
# SFHH006i      2847  10243648           277.928332  Lexogen
# SFHH006j        26    937430            27.735404  Lexogen
# SFHH006l       213   6208092            34.310059  Lexogen
# SFHH006m       165   4216486            39.132111  Lexogen
# SFHH006n       237   8372976            28.305348  Lexogen
# SFHH006o       221   6188796            35.709692  Lexogen
# SFHH006p       275   3635870            75.635267  Lexogen
# SFHH006q        57   2256000            25.265957  Lexogen
# SFHH006r       112   3231390            34.660007  Lexogen
# SFHH006s        92   4090252            22.492502  Lexogen
# SFHH006t       575   4263646           134.861102  Lexogen
# SFHH006u       184   7617880            24.153702  Lexogen
# SFHH006w        52    972694            53.459773  Lexogen
# SFHH006x       119   7358578            16.171603  Lexogen
# SFHH006y      1248   7306438           170.808265  Lexogen
# SFHH006z      2505   9705956           258.088951  Lexogen

# %%
cats=cats_LTR+cats_Retroposon
cats['assigned per million']=1e6*cats['Assigned']/cats['sum']
cats['library']='CATS'
#cats.drop(['SFHH005ag','SFHH005ar','SFHH005k','SFHH005v'],inplace=True,axis='index')
cats.drop(['SFHH005ag','SFHH005k'],inplace=True,axis='index')
cats
# Out:
# Status    Assigned       sum assigned per million library
# SFHH005aa    18265   2768292          6597.931143    CATS
# SFHH005ab    35285   2725456           12946.4574    CATS
# SFHH005ac    96512   4063528         23750.789954    CATS
# SFHH005a     93339   6313054         14785.078664    CATS
# SFHH005ad    22101   2396664          9221.567979    CATS
# SFHH005ae    37355   3611530          10343.26172    CATS
# SFHH005af    59435   4505592         13191.385283    CATS
# SFHH005ah    44266   2417028         18314.227225    CATS
# SFHH005ai    20286   2503202          8104.020371    CATS
# SFHH005aj   244183   6723142         36319.774296    CATS
# SFHH005ak    14369   2013640          7135.833615    CATS
# SFHH005al    46488   2533834         18346.900389    CATS
# SFHH005am    84648   4343220         19489.687375    CATS
# SFHH005an    17628   1303334         13525.312775    CATS
# SFHH005ao    12066   1937432           6227.83148    CATS
# SFHH005ap    17287   1979018          8735.140357    CATS
# SFHH005aq    11446    722194          15848.92702    CATS
# SFHH005b      4747   5081320           934.206072    CATS
# SFHH005c     62502   6296282          9926.810775    CATS
# SFHH005d      8857   4331674          2044.706042    CATS
# SFHH005e     14463   6241972          2317.056212    CATS
# SFHH005f     13912   4346960          3200.397519    CATS
# SFHH005g    357816   9876038         36230.723292    CATS
# SFHH005h     22736  20136948          1129.068814    CATS
# SFHH005i     95641   6354170         15051.690465    CATS
# SFHH005j      6498   5135412          1265.331779    CATS
# SFHH005l      6512   2603752           2501.00624    CATS
# SFHH005m     12869   2568118          5011.062576    CATS
# SFHH005n     16445   4689114          3507.059116    CATS
# SFHH005o      6962   1465562          4750.396094    CATS
# SFHH005p     30560   2980536         10253.189359    CATS
# SFHH005q     12514   2421382          5168.122998    CATS
# SFHH005r      8350   1939872          4304.407713    CATS
# SFHH005s     12728   1459206          8722.551854    CATS
# SFHH005t     73496   3467250         21197.202394    CATS
# SFHH005u      9353   2275514          4110.280139    CATS
# SFHH005w     76658   3879240         19761.087223    CATS
# SFHH005x     14873   2131088          6979.064215    CATS
# SFHH005y    129107   4100068         31488.989939    CATS
# SFHH005z    100808   3278986         30743.650629    CATS

# %% [markdown]
# control
#
# SFHH005k | SFHH005ag | SFHH006k | SFHH006ag

# %%
#df.plot( y='assigned per million')

# %%
#meta=pd.read_csv('metadata.csv')
##meta.drop(['Rand 2 Batch_order'],inplace=True,axis='columns')
###meta.drop([Lexogen Sequencing ID'],inplace=True,axis='columns')
###meta.drop(meta[meta['Diagnosis'].str.contains('blank')].index,inplace=True)
###meta.set_index('D-plex Sequencing ID',inplace=True)
#meta.drop(['Diagnosis'],inplace=True,axis='columns')
#meta.set_index('Rand 2 Batch_order',inplace=True)
#meta

# %%
#df=meta.merge(cats,left_on='D-plex Sequencing ID',right_index=True)
#df
#df=df.merge(meta,left_index=True,right_index=True)
#df

# %%
# Drop *ar, *ag, *v, *k

# %%
df=pd.concat([cats,lex])
df
# Out:
# Status    Assigned      sum assigned per million  library
# SFHH005aa    18265  2768292          6597.931143     CATS
# SFHH005ab    35285  2725456           12946.4574     CATS
# SFHH005ac    96512  4063528         23750.789954     CATS
# SFHH005a     93339  6313054         14785.078664     CATS
# SFHH005ad    22101  2396664          9221.567979     CATS
# ...            ...      ...                  ...      ...
# SFHH006u       184  7617880            24.153702  Lexogen
# SFHH006w        52   972694            53.459773  Lexogen
# SFHH006x       119  7358578            16.171603  Lexogen
# SFHH006y      1248  7306438           170.808265  Lexogen
# SFHH006z      2505  9705956           258.088951  Lexogen
#
# [80 rows x 4 columns]

# %%
df.dtypes
# Out:
# Status
# Assigned                object
# sum                     object
# assigned per million    object
# library                 object
# dtype: object

# %%
df['assigned per million']=df['assigned per million'].astype(float)

# %%
df.dtypes
# Out:
# Status
# Assigned                 object
# sum                      object
# assigned per million    float64
# library                  object
# dtype: object

# %%
ax=df.boxplot(column='assigned per million',by=['library'])
ax.set_xlabel("Preparation Library")
ax.set_ylabel("Assigned per million")
plt.title('')
plt.suptitle('')
plt.show()

# %%
ax=sns.boxplot(x="library", y="assigned per million", data=df)
ax.set_xlabel("Preparation Library")
ax.set_ylabel("Assigned per million")
plt.show()

# %%
ax=sns.swarmplot(x="library", y="assigned per million", data=df,size=5,
    edgecolor='black',linewidth=1,linestyle='-')
ax.set_xlabel("Preparation Library")
ax.set_ylabel("Assigned per million")
plt.show()
# Out:
# /Users/jake/Library/Python/3.8/lib/python/site-packages/seaborn/categorical.py:1296: UserWarning: 42.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
ax=sns.boxplot(x="library", y="assigned per million", data=df)
ax=sns.swarmplot(x="library", y="assigned per million", data=df,size=5,
    edgecolor='black',linewidth=1,linestyle='-')
ax.set_xlabel("Preparation Library")
ax.set_ylabel("Assigned per million")
plt.show()
# Out:
# /Users/jake/Library/Python/3.8/lib/python/site-packages/seaborn/categorical.py:1296: UserWarning: 42.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
ax=sns.stripplot(x="library", y="assigned per million", data=df,size=5,
    edgecolor='black',linewidth=1,linestyle='-')
ax.set_xlabel("Preparation Library")
ax.set_ylabel("Assigned per million")
plt.show()

# %%
ax=sns.violinplot(x="library", y="assigned per million", data=df)
ax.set_xlabel("Preparation Library")
ax.set_ylabel("Assigned per million")
plt.show()
