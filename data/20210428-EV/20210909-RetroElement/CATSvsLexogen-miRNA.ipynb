# %%
import pandas as pd
pd.__version__
# Out:
# '1.3.2'

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.4.2'

# %%
import matplotlib.pyplot as plt

# %%
# Adjust plot size
#options(repr.plot.width=16, repr.plot.height=6)

# For some reason, if this is in the same cell as the import command, it doesn't work.
#plt.rcParams["figure.figsize"] = [18.0,8.0]

# %%
import seaborn as sns
sns.__version__
# Out:
# '0.11.2'

# %%
df = pd.read_csv('feature_counts.5.cutadapt2.mirna.summary.tsv',sep="\t")
sum=df.sum().to_frame().T
sum['Status']='sum'
sum
df=pd.concat([df,sum],axis='index')
del(sum)
df.set_index('Status',inplace=True)
df=df.T
df.drop(['Unassigned_Read_Type','Unassigned_Singleton','Unassigned_MappingQuality','Unassigned_Chimera',
    'Unassigned_FragmentLength','Unassigned_Duplicate','Unassigned_MultiMapping','Unassigned_Secondary',
    'Unassigned_NonSplit','Unassigned_Overlapping_Length',
    'Unassigned_Unmapped','Unassigned_NoFeatures','Unassigned_Ambiguity'],axis='columns',inplace=True)
#df['assigned per million']=1e6*df['Assigned']/df['sum']
cats=df
del(df)
cats
# Out:
# Status    Assigned       sum
# SFHH005aa       40   1384146
# SFHH005ab       16   1362728
# SFHH005ac       45   2031764
# SFHH005a       109   3156527
# SFHH005ad        8   1198332
# SFHH005ae       15   1805765
# SFHH005af       54   2252796
# SFHH005ag       24   1298583
# SFHH005ah       65   1208514
# SFHH005ai        2   1251601
# SFHH005aj      159   3361571
# SFHH005ak       93   1006820
# SFHH005al        7   1266917
# SFHH005am      113   2171610
# SFHH005an       35    651667
# SFHH005ao       61    968716
# SFHH005ap       16    989509
# SFHH005aq       34    361097
# SFHH005b        27   2540660
# SFHH005c        68   3148141
# SFHH005d        19   2165837
# SFHH005e        83   3120986
# SFHH005f        10   2173480
# SFHH005g       389   4938019
# SFHH005h        80  10068474
# SFHH005i       132   3177085
# SFHH005j        41   2567706
# SFHH005k        48   1127360
# SFHH005l         6   1301876
# SFHH005m       160   1284059
# SFHH005n        20   2344557
# SFHH005o        32    732781
# SFHH005p       145   1490268
# SFHH005q        59   1210691
# SFHH005r        32    969936
# SFHH005s        39    729603
# SFHH005t       127   1733625
# SFHH005u         3   1137757
# SFHH005w        87   1939620
# SFHH005x        11   1065544
# SFHH005y       166   2050034
# SFHH005z        21   1639493

# %%
df = pd.read_csv('feature_counts.6.cutadapt2.mirna.summary.tsv',sep="\t")
sum=df.sum().to_frame().T
sum['Status']='sum'
sum
df=pd.concat([df,sum],axis='index')
del(sum)
df.set_index('Status',inplace=True)
df=df.T
df.drop(['Unassigned_Read_Type','Unassigned_Singleton','Unassigned_MappingQuality','Unassigned_Chimera',
    'Unassigned_FragmentLength','Unassigned_Duplicate','Unassigned_MultiMapping','Unassigned_Secondary',
    'Unassigned_NonSplit','Unassigned_Overlapping_Length',
    'Unassigned_Unmapped','Unassigned_NoFeatures','Unassigned_Ambiguity'],axis='columns',inplace=True)
#df['assigned per million']=1e6*df['Assigned']/df['sum']
lex=df
del(df)
lex
# Out:
# Status    Assigned      sum
# SFHH006aa     9736  4524940
# SFHH005y       166   2050034            80.974267    CATS
# SFHH005z        21   1639493            12.808838    CATS

# %% [markdown]
# control
#
# SFHH005k | SFHH005ag | SFHH006k | SFHH006ag

# %%
#df.plot( y='assigned per million')

# %%
#meta=pd.read_csv('metadata.csv')
##meta.drop(['Rand 2 Batch_order'],inplace=True,axis='columns')
###meta.drop([Lexogen Sequencing ID'],inplace=True,axis='columns')
###meta.drop(meta[meta['Diagnosis'].str.contains('blank')].index,inplace=True)
###meta.set_index('D-plex Sequencing ID',inplace=True)
#meta.drop(['Diagnosis'],inplace=True,axis='columns')
#meta.set_index('Rand 2 Batch_order',inplace=True)
#meta

# %%
#df=meta.merge(cats,left_on='D-plex Sequencing ID',right_index=True)
#df
#df=df.merge(meta,left_index=True,right_index=True)
#df

# %%
# Drop *ar, *ag, *v, *k

# %%
df=pd.concat([cats,lex])
df
# Out:
# Status    Assigned      sum assigned per million  library
# SFHH005aa       40  1384146            28.898686     CATS
# SFHH005ab       16  1362728            11.741155     CATS
# SFHH005ac       45  2031764            22.148242     CATS
# SFHH005a       109  3156527            34.531623     CATS
# SFHH005ad        8  1198332             6.675946     CATS
# ...            ...      ...                  ...      ...
# SFHH006u       554  3808940            145.44729  Lexogen
# SFHH006w       995   486347          2045.864373  Lexogen
# SFHH006x      8217  3679289          2233.311925  Lexogen
# SFHH006y     11361  3653219          3109.860099  Lexogen
# SFHH006z      9902  4852978          2040.396639  Lexogen
#
# [80 rows x 4 columns]

# %%
df.dtypes
# Out:
# Status
# Assigned                object
# sum                     object
# assigned per million    object
# library                 object
# dtype: object

# %%
df['assigned per million']=df['assigned per million'].astype(float)

# %%
df.dtypes
# Out:
# Status
# Assigned                 object
# sum                      object
# assigned per million    float64
# library                  object
# dtype: object

# %%
ax=df.boxplot(column='assigned per million',by=['library'])
ax.set_xlabel("Preparation Library")
ax.set_ylabel("Assigned per million")
plt.title('')
plt.suptitle('')
plt.show()

# %%
ax=sns.boxplot(x="library", y="assigned per million", data=df)
ax.set_xlabel("Preparation Library")
ax.set_ylabel("Assigned per million")
plt.show()

# %%
ax=sns.swarmplot(x="library", y="assigned per million", data=df,size=5,
    edgecolor='black',linewidth=1,linestyle='-')
ax.set_xlabel("Preparation Library")
ax.set_ylabel("Assigned per million")
plt.show()
# Out:
# /Users/jake/Library/Python/3.8/lib/python/site-packages/seaborn/categorical.py:1296: UserWarning: 47.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
ax=sns.boxplot(x="library", y="assigned per million", data=df)
ax=sns.swarmplot(x="library", y="assigned per million", data=df,size=5,
    edgecolor='black',linewidth=1,linestyle='-')
ax.set_xlabel("Preparation Library")
ax.set_ylabel("Assigned per million")
plt.show()
# Out:
# /Users/jake/Library/Python/3.8/lib/python/site-packages/seaborn/categorical.py:1296: UserWarning: 47.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
ax=sns.stripplot(x="library", y="assigned per million", data=df,size=5,
    edgecolor='black',linewidth=1,linestyle='-')
ax.set_xlabel("Preparation Library")
ax.set_ylabel("Assigned per million")
plt.show()

# %%
ax=sns.violinplot(x="library", y="assigned per million", data=df)
ax.set_xlabel("Preparation Library")
ax.set_ylabel("Assigned per million")
plt.show()
