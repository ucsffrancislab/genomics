# %%
import numpy as np
np.__version__
# Out:
# '1.21.2'

# %%
import pandas as pd
pd.__version__
# Out:
# '1.3.2'

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.4.2'

# %%
import matplotlib.pyplot as plt

# %%
# Adjust plot size
#options(repr.plot.width=16, repr.plot.height=6)

# For some reason, if this is in the same cell as the import command, it doesn't work.
plt.rcParams["figure.figsize"] = [18.0,8.0]

# %%
default_max_rows=pd.get_option('display.max_rows')

# %%
pd.set_option('display.max_rows',1000)

# %%
df=pd.read_csv("report.csv",sep=",")
df.head()
# Out:
#      accession                                        description   length  \
# 0  NC_000117.1  Chlamydia trachomatis D UW-3 CX chromosome  co...  1042519
# 1  NC_000875.1  Anopheles quadrimaculatus A mitochondrion  com...    15455
# 2  NC_001276.1   Crassostrea gigas mitochondrion  complete genome    18224
# 3  NC_001631.1      Pinus thunbergii chloroplast  complete genome   119707
# 4  NC_001636.1  Katharina tunicata mitochondrion  complete genome    15532
#
#    raw Ns  raw Ns %  masked Ns  masked Ns %  vsl-25 Ns  vsl-25 Ns %  \
# 0       0         0       4939         0.47        858         0.08
# 1       0         0        714         4.61        984         6.36
# 2       0         0         82         0.44        245         1.34
# 3       0         0       2574         2.15        466         0.38
# 4       0         0        363         2.33        451         2.90
#
#    masked vsl-25 Ns  masked vsl-25 Ns %
# 0              5650                0.54
# 1              1599               10.34
# 2               327                1.79
# 3              2819                2.35
# 4               706                4.54

# %%
df.drop(0,inplace=True)
df.head()
# Out:
#      accession                                        description  length  \
# 1  NC_000875.1  Anopheles quadrimaculatus A mitochondrion  com...   15455
# 2  NC_001276.1   Crassostrea gigas mitochondrion  complete genome   18224
# 3  NC_001631.1      Pinus thunbergii chloroplast  complete genome  119707
# 4  NC_001636.1  Katharina tunicata mitochondrion  complete genome   15532
# 5  NC_001637.1  Acanthamoeba castellanii mitochondrion  comple...   41591
#
#    raw Ns  raw Ns %  masked Ns  masked Ns %  vsl-25 Ns  vsl-25 Ns %  \
# 1       0         0        714         4.61        984         6.36
# 2       0         0         82         0.44        245         1.34
# 3       0         0       2574         2.15        466         0.38
# 4       0         0        363         2.33        451         2.90
# 5       0         0       1444         3.47        343         0.82
#
#    masked vsl-25 Ns  masked vsl-25 Ns %
# 1              1599               10.34
# 2               327                1.79
# 3              2819                2.35
# 4               706                4.54
# 5              1689                4.06

# %%
df.set_index('accession',inplace=True)
df.head()
# Out:
#                                                    description  length  \
# accession
# NC_000875.1  Anopheles quadrimaculatus A mitochondrion  com...   15455
# NC_001276.1   Crassostrea gigas mitochondrion  complete genome   18224
# NC_001631.1      Pinus thunbergii chloroplast  complete genome  119707
# NC_001636.1  Katharina tunicata mitochondrion  complete genome   15532
# NC_001637.1  Acanthamoeba castellanii mitochondrion  comple...   41591
#
#              raw Ns  raw Ns %  masked Ns  masked Ns %  vsl-25 Ns  vsl-25 Ns %  \
# accession
# NC_000875.1       0         0        714         4.61        984         6.36
# NC_001276.1       0         0         82         0.44        245         1.34
# NC_001631.1       0         0       2574         2.15        466         0.38
# NC_001636.1       0         0        363         2.33        451         2.90
# NC_001637.1       0         0       1444         3.47        343         0.82
#
#              masked vsl-25 Ns  masked vsl-25 Ns %
# accession
# NC_000875.1              1599               10.34
# NC_001276.1               327                1.79
# NC_001631.1              2819                2.35
# NC_001636.1               706                4.54
# NC_001637.1              1689                4.06

# %%
df['masked Ns %'].plot(kind='bar')
plt.show()

# %%
#df[['masked vsl-25 Ns %','masked vsl-100 Ns %']].plot(kind='bar')
df[['masked vsl-25 Ns %']].plot(kind='bar')
plt.show()

# %%
df
# Out:
#                                                      description   length  \
# accession
# NC_000875.1    Anopheles quadrimaculatus A mitochondrion  com...    15455
# NC_001276.1     Crassostrea gigas mitochondrion  complete genome    18224
# NC_001631.1        Pinus thunbergii chloroplast  complete genome   119707
# NC_001636.1    Katharina tunicata mitochondrion  complete genome    15532
# NC_001637.1    Acanthamoeba castellanii mitochondrion  comple...    41591
# ...                                                          ...      ...
# NZ_AP017310.1  Leptolyngbya sp. NIES-3755 plasmid plasmid2 DN...    98206
# NZ_CP006975.1  Chlamydia muridarum str. Nigg CM972  complete ...  1072952
# NZ_CP007244.1  Bacillus amyloliquefaciens subsp. plantarum Tr...  3957904
# NZ_CP010451.1  Corynebacterium glutamicum strain B253  comple...  3207539
# NZ_CP011980.1    Klebsiella pneumoniae 500 1420  complete genome  5308211
#
#                raw Ns  raw Ns %  masked Ns  masked Ns %  vsl-25 Ns  \
# accession
# NC_000875.1         0         0        714         4.61        984
# NC_001276.1         0         0         82         0.44        245
# NC_001631.1         0         0       2574         2.15        466
# NC_001636.1         0         0        363         2.33        451
# NC_001637.1         0         0       1444         3.47        343
# ...               ...       ...        ...          ...        ...
# NZ_AP017310.1       0         0        142         0.14         49
# NZ_CP006975.1       0         0       5093         0.47        858
# NZ_CP007244.1       0         0      18225         0.46       1789
# NZ_CP010451.1       0         0      16673         0.51        540
# NZ_CP011980.1       0         0      34021         0.64       1127
#
#                vsl-25 Ns %  masked vsl-25 Ns  masked vsl-25 Ns %
# accession
# NC_000875.1           6.36              1599               10.34
# NC_001276.1           1.34               327                1.79
# NC_001631.1           0.38              2819                2.35
# NC_001636.1           2.90               706                4.54
# NC_001637.1           0.82              1689                4.06
# ...                    ...               ...                 ...
# NZ_AP017310.1         0.04               191                0.19
# NZ_CP006975.1         0.07              5755                0.53
# NZ_CP007244.1         0.04             19622                0.49
# NZ_CP010451.1         0.01             16967                0.52
# NZ_CP011980.1         0.02             34854                0.65
#
# [5328 rows x 10 columns]

# %%
#cols=

# %%
#df[(df['masked vsl-25 Ns %']>1) | (df['masked vsl-100 Ns %']>1)][
#    ['masked vsl-25 Ns %','masked vsl-50 Ns %','masked vsl-75 Ns %','masked vsl-100 Ns %']].plot(kind='bar')
df[(df['masked vsl-25 Ns %']>1)][
    ['masked vsl-25 Ns %','masked Ns %']].plot(kind='bar')
plt.show()

# %%
#df[(df['masked vsl-25 Ns %']>1) | (df['masked vsl-100 Ns %']>1)]['description']
df[(df['masked vsl-25 Ns %']>1)]['description']
# Out:
# accession
# NC_000875.1      Anopheles quadrimaculatus A mitochondrion  com...
# NC_001276.1       Crassostrea gigas mitochondrion  complete genome
# NC_001631.1          Pinus thunbergii chloroplast  complete genome
# NC_001636.1      Katharina tunicata mitochondrion  complete genome
# NC_001637.1      Acanthamoeba castellanii mitochondrion  comple...
#                                        ...
# NC_034369.1      Fritillaria ussuriensis chloroplast  complete ...
# NC_034370.1           Lilium taliense chloroplast  complete genome
# NC_034371.1      Primula kwangtungensis chloroplast  complete g...
# NC_034374.1      Numida meleagris isolate 19003 mitochondrion  ...
# NZ_AP014883.1    Acetobacter pasteurianus NBRC 101655 plasmid p...
# Name: description, Length: 5246, dtype: object

# %%
df[(df['masked vsl-25 Ns %']>3) | 
   (df['masked c1-25 Ns %']>3) | 
   (df['masked c2-25 Ns %']>3) | 
   (df['masked c3-25 Ns %']>3) |
   (df['masked c4-25 Ns %']>3) |
   (df['masked c5-25 Ns %']>3) |
   (df['masked c6-25 Ns %']>3) |
   (df['masked c7-25 Ns %']>3) |
   (df['masked c8-25 Ns %']>3)
   | (df['masked c9-25 Ns %']>3)
   | (df['masked c10-25 Ns %']>3)
   | (df['masked c11-25 Ns %']>3)
   | (df['masked c12-25 Ns %']>3)
  ][
    ['masked Ns %','masked vsl-25 Ns %','masked c1-25 Ns %','masked c2-25 Ns %','masked c3-25 Ns %',
     'masked c4-25 Ns %','masked c5-25 Ns %','masked c6-25 Ns %','masked c7-25 Ns %','masked c8-25 Ns %'
     ,'masked c9-25 Ns %'
     ,'masked c10-25 Ns %'
     ,'masked c11-25 Ns %'
     ,'masked c12-25 Ns %'
    ]].plot(kind='bar')
plt.show()

# %%
df[(df['masked vsl-25 Ns %']>3)]['description']

# %%
pd.set_option('display.max_rows',default_max_rows)
