# %%
import pandas as pd
pd.__version__
# Out:
# '1.3.5'

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.4.2'

# %%
#import matplotlib.pyplot as plt

# %%
# Adjust plot size
#options(repr.plot.width=16, repr.plot.height=6)

# For some reason, if this is in the same cell as the import command, it doesn't work.
#plt.rcParams["figure.figsize"] = [18.0,8.0]

# %%
import seaborn as sns
sns.__version__
# Out:
# '0.11.2'

# %%
df = pd.read_csv('merged.csv',sep=",",index_col=0)
df=df.fillna(0)
df=df.astype(int)
df.head()
# Out:
#              10-PAKSWW-03A-02R  10-PAKSWW-04A-01R  10-PAMXHJ-09A-01R  \
# item
# AC_000002.1                  0                  0                  0
# AC_000007.1                  0                  0                  0
# AC_000008.1                  0                  0                  0
# AC_000017.1                  0                  0                  0
# NC_000871.1                  0                  0                  0
#
#              10-PAMXSP-09A-01R  10-PANATY-09B-01R  10-PANCVR-03A-01R  \
# item
# AC_000002.1                  0                  0                  0
# AC_000007.1                  0                  0                  0
# AC_000008.1                  0                  0                  0
# AC_000017.1                  0                  0                  0
# NC_000871.1                  0                  0                  0
#
#              10-PANCVR-04A-02R  10-PANDBX-09B-01R  10-PANDWE-03A-02R  \
# item
# AC_000002.1                  0                  0                  0
# AC_000007.1                  0                  0                  0
# AC_000008.1                  0                  0                  0
# AC_000017.1                  0                  0                  0
# NC_000871.1                  0                  0                  0
#
#              10-PANEUH-09A-01R  ...  10-PAUAZV-09A-01R  10-PAUBCB-09A-01R  \
# item                            ...
# AC_000002.1                  0  ...                  0                  0
# AC_000007.1                  0  ...                  0                  0
# AC_000008.1                  0  ...                  0                  0
# AC_000017.1                  0  ...                  0                  0
# NC_000871.1                  0  ...                  0                  0
#
#              10-PAUBCT-09A-01R  10-PAUBLL-09A-01R  10-PAUBPY-09A-01R  \
# item
# AC_000002.1                  0                  0                  0
# AC_000007.1                  0                  0                  0
# AC_000008.1                  0                  0                  0
# AC_000017.1                  0                  0                  0
# NC_000871.1                  0                  0                  0
#
#              10-PAUBRD-09A-01R  10-PAUBTC-09A-01R  10-PAUBXP-09A-01R  \
# item
# AC_000002.1                  0                  0                  0
# AC_000007.1                  0                  0                  0
# AC_000008.1                  0                  0                  0
# AC_000017.1                  0                  0                  0
# NC_000871.1                  0                  0                  0
#
#              10-PAUCDC-09A-01R  10-PAUCDY-09A-01R
# item
# AC_000002.1                  0                  0
# AC_000007.1                  0                  0
# AC_000008.1                  0                  0
# AC_000017.1                  0                  0
# NC_000871.1                  0                  0
#
# [5 rows x 532 columns]

# %%
#viral_count=df.loc['Viral aligned pair Count'] #.astype(int)
#df=df.drop('Viral aligned pair Count')
#df.head()

# %%
#hg38_count=df.loc['HG38 aligned pair Count'] #.astype(int)
#df=df.drop('HG38 aligned pair Count')
#df.head()

# %%
df.shape
# Out:
# (897, 532)

# %%
default_max_rows=pd.get_option('display.max_rows')
pd.set_option('display.max_rows',1000)

#default_max_cols=pd.get_option('display.max_columns')
#pd.set_option('display.max_columns', 1000)

default_max_seq_items=pd.get_option('display.max_seq_items')
pd.set_option('display.max_seq_items', None)

# %%
#df.columns.str.split('-',expand=True).get_level_values(2)
#df.columns.str.match('^..-....-01')

# %%
pd.set_option('display.max_seq_items', default_max_seq_items)
pd.set_option('display.max_rows',default_max_rows)

# %%
df.shape
# Out:
# (897, 532)

# %% [markdown]
# ## Drop all but the 01's. There are some 02's and 11's.

# %%
#df.columns.str.split('-',expand=True).get_level_values(2).str.contains("01.")
#df.columns.str.match('^..-....-01')[0:9]

# %%
#df=df.iloc[:,df.columns.str.match('..-....-01.-...-....-..+.')]
#df=df.iloc[:,df.columns.str.match('^..-....-01')]

# %%
df.shape
# Out:
# (897, 532)

# %%
df.columns
# Out:
# Index(['10-PAKSWW-03A-02R', '10-PAKSWW-04A-01R', '10-PAMXHJ-09A-01R',
#        '10-PAMXSP-09A-01R', '10-PANATY-09B-01R', '10-PANCVR-03A-01R',
#        '10-PANCVR-04A-02R', '10-PANDBX-09B-01R', '10-PANDWE-03A-02R',
#        '10-PANEUH-09A-01R',
#        ...
#        '10-PAUAZV-09A-01R', '10-PAUBCB-09A-01R', '10-PAUBCT-09A-01R',
#        '10-PAUBLL-09A-01R', '10-PAUBPY-09A-01R', '10-PAUBRD-09A-01R',
#        '10-PAUBTC-09A-01R', '10-PAUBXP-09A-01R', '10-PAUCDC-09A-01R',
#        '10-PAUCDY-09A-01R'],
#       dtype='object', length=532)

# %%
max(df.sum(axis='columns'))
# Out:
# 129655

# %%
(df.sum(axis='columns')>1000)
# Out:
# item
# AC_000002.1    False
# AC_000007.1    False
# AC_000008.1    False
# AC_000017.1    False
# NC_000871.1    False
#                ...
# NC_055772.1    False
# NC_055833.1    False
# NC_055875.1    False
# NC_055886.1    False
# NC_055914.1    False
# Length: 897, dtype: bool

# %%
#tmp=df.iloc[(df.sum(axis='columns')>100).values,:]
#tmp.shape

# %% [markdown]
# ## Select only the common viruses ( sum > 1000 )

# %%
df=df.iloc[(df.sum(axis='columns')>1000).values,:]

# %%
df.shape
# Out:
# (17, 532)

# %%
df
# Out:
#              10-PAKSWW-03A-02R  10-PAKSWW-04A-01R  10-PAMXHJ-09A-01R  \
# item
# NC_001479.1                 14                 16                 13
# NC_001506.1                723                282                478
# NC_004812.1                  3                 12                  1
# NC_006553.1                  3                 10                  3
# NC_013221.1                  1                  8                  0
# NC_020235.1                  9                 50                 11
# NC_021095.1                  3                 10                  4
# NC_024502.1                 10                 52                  6
# NC_031032.1                  1                 10                  2
# NC_038828.1                  0                  8                  2
# NC_038858.1                721                279                482
# NC_040615.1                 11                 23                  3
# NC_041925.1                  0                  6                  1
# NC_042057.1                  0                  3                  1
# NC_043054.1                 74                197                 64
# NC_048867.1                  3                 15                  4
# NC_049835.1                  4                  6                  1
#
#              10-PAMXSP-09A-01R  10-PANATY-09B-01R  10-PANCVR-03A-01R  \
# item
# NC_001479.1                 14                  8                  4
# NC_001506.1                374                 62                483
# NC_004812.1                  3                  1                  2
# NC_006553.1                  7                  0                  2
# NC_013221.1                  8                  0                  1
# NC_020235.1                 56                  0                 12
# NC_021095.1                  6                  0                  2
# NC_024502.1                 57                  0                 13
# NC_031032.1                 17                  0                  0
# NC_038828.1                  8                  0                  2
# NC_040615.1                 20                 48                 72
# NC_041925.1                156                140                202
# NC_042057.1                  0                  2                  4
# NC_043054.1                195                365                703
# NC_048867.1                  0                  0                  3
# NC_049835.1                  0                  3                  1
#
#              10-PAUCDC-09A-01R  10-PAUCDY-09A-01R
# item
# NC_001479.1                 29                 19
# NC_001506.1                 10                 39
# NC_004812.1                  3                  0
# NC_006553.1                  1                  0
# NC_013221.1                  0                  0
# NC_020235.1                  0                  0
# NC_021095.1                  0                  0
# NC_024502.1                  1                  0
# NC_031032.1                  0                  0
# NC_038828.1                  1                  0
# NC_038858.1                 12                 31
# NC_040615.1                 22                 17
# NC_041925.1                 59                 50
# NC_042057.1                  0                  0
# NC_043054.1                265                144
# NC_048867.1                  0                  2
# NC_049835.1                  0                  0
#
# [17 rows x 532 columns]

# %%
ref=pd.read_csv('viral.csv',sep=',',index_col=0,header=None)
ref.index.name=None
ref
# Out:
#                                                              1
# AC_000001.1                 Ovine_adenovirus_A_complete_genome
# AC_000002.1                Bovine_adenovirus_B_complete_genome
# AC_000003.1                Canine_adenovirus_1_complete_genome
# AC_000004.1                  Duck_adenovirus_A_complete_genome
# AC_000005.1             Human_mastadenovirus_A_complete_genome
# ...                                                        ...
# NC_055918.1  Mycobacterium_phage_OhShagHennessy_complete_ge...
# NC_055919.1      Klebsiella_phage_vB_KpnP_P184_complete_genome
# NC_055920.1               Gordonia_phage_Phlop_complete_genome
# NC_055921.1       Salmonella_phage_vB_SalP_TR2_complete_genome
# NC_056724.1     Lactococcus_lactis_phage_BK5-T_complete_genome
#
# [14721 rows x 1 columns]

# %%
df.sum(axis='columns').to_frame().join(ref,how='left').sort_values(0)
# Out:
#                   0                                                  1
# item
# NC_049835.1    1009  Klebsiella_phage_vB_KpnS_Domnhall_complete_genome
# NC_013221.1    1099  Phytophthora_infestans_RNA_virus_1_RNA2A_compl...
# NC_021095.1    1146  White_clover_cryptic_virus_2_isolate_IPP_Lirep...
# NC_042057.1    1160           Enterobacteria_phage_DE3_complete_genome
# NC_006553.1    1276                  Avian_sapelovirus_complete_genome
# NC_038828.1    1420  Heterobasidion_RNA_virus_1_isolate_HetRV1-ab1_...
# NC_031032.1    1516              Bacillus_phage_Stitch_complete_genome
# NC_004812.1    1528             Macacine_herpesvirus_1_complete_genome
# NC_048867.1    1699        Salmonella_phage_faergetype_complete_genome
# NC_020235.1    6284  Rosellinia_necatrix_partitivirus_2_CP_gene_for...
# NC_024502.1    6316  Gentian_ovary_ring-spot_virus_genomic_RNA_segm...
# NC_001479.1   10361         Encephalomyocarditis_virus_complete_genome
# NC_040615.1   10731  Eptesicus_fuscus_gammaherpesvirus_complete_genome
# NC_041925.1   34597      Proteus_phage_VB_PmiS-Isfahan_complete_genome
# NC_038858.1   90667  FBR_murine_osteosarcoma_complete_proviral_sequ...
# NC_001506.1   91555          Murine_osteosarcoma_virus_complete_genome
# NC_043054.1  129655  Bubaline_alphaherpesvirus_1_strain_b6_complete...
