# %%
import numpy as np
np.__version__
# Out:
# '1.20.3'

# %%
import pandas as pd
pd.__version__
# Out:
# '1.2.4'

# %%
df=pd.read_csv("report.csv",sep=",")
df.head()
# Out:
#     accession                                        description length  \
# 0         ---                                                ---    ---
# 1  AB027020.1  Human papillomavirus type 69 DNA  complete genome   7700
# 2  AB027021.1  Human papillomavirus type 82 DNA  complete genome   7871
# 3  AB745694.1  Human papillomavirus 160 DNA  complete genome ...   7779
# 4  AF131950.1    Human papillomavirus candHPV85  complete genome   7812
#
#   masked Ns masked Ns % custom-25 Ns custom-25 Ns % masked custom-25 Ns  \
# 0       ---         ---          ---            ---                 ---
# 1       192        2.49          369           4.79                 487
# 2       124        1.57          395           5.01                 419
# 3        37         .47           98           1.25                 135
# 4         0           0          245           3.13                   0
#
#   masked custom-25 Ns % dev-25 Ns  ... masked custom-100 Ns  \
# ...
