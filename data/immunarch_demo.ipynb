# %%
options(repr.plot.width = 10, repr.plot.height = 6, repr.plot.res = 250)

# %%
# Load the package into R
library(immunarch)
# Out:
# Loading required package: ggplot2
#
# Loading required package: dplyr
#
#
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: dtplyr
#
# Loading required package: data.table
#
#
# Attaching package: ‘data.table’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     between, first, last
#
#
# Loading required package: patchwork

# %%
# Load the test dataset
data(immdata)

# %%
# Visualise the length distribution of CDR3
repExplore(immdata$data, "lens") %>% vis()
# Out:
# plot without title

# %%
repClonality(immdata$data, "homeo") %>% vis()
# Out:
# plot without title

# %%
# Visualise the relative abundance of clonotypes
p = repClonality(immdata$data, "homeo") %>% vis()
#p + theme(legend.position = "none") + geom_bar(stat="identity",color="red",fill="white",width=NULL)+
# theme_classic()
#geom_bar(color = "red") 
#print(class(p))
p +   geom_bar(colour = "NA") + coord_flip()
# cannot get the black bar borders to go away no matter what I've tried
# Out:
# plot without title

# %%
options(repr.plot.width = 10, repr.plot.height = 12, repr.plot.res = 250)
repClonality(immdata$data, "homeo") %>% vis() + coord_flip()
# Out:
# plot without title

# %%
options(repr.plot.width = 10, repr.plot.height = 6, repr.plot.res = 250)

# %%
# Build the heatmap of public clonotypes shared between repertoires
repOverlap(immdata$data) %>% vis()
# Out:
# plot without title

# %%
# Build the heatmap of public clonotypes shared between repertoires
p = repOverlap(immdata$data) %>% vis()
p + geom_tile() #aes(fill = value))
# Out:
# plot without title

# %%
# Visualise the V-gene distribution for the first repertoire
geneUsage(immdata$data[[1]]) %>% vis()
# Out:
# Using Names as id variables
# plot without title

# %%
# Visualise the Chao1 diversity of repertoires, grouped by the patient status
repDiversity(immdata$data) %>% vis(.by = "Status", .meta = immdata$meta)
# Out:
# Warning message:
# “Ignoring unknown aesthetics: xmin, xmax, annotations, y_position”
# plot without title
