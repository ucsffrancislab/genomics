# %%
import pandas as pd
pd.__version__
# Out:
# '1.3.5'

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.4.2'

# %%
#import matplotlib.pyplot as plt

# %%
# Adjust plot size
#options(repr.plot.width=16, repr.plot.height=6)

# For some reason, if this is in the same cell as the import command, it doesn't work.
#plt.rcParams["figure.figsize"] = [18.0,8.0]

# %%
import seaborn as sns
sns.__version__
# Out:
# '0.11.2'

# %%
df = pd.read_csv('merged.csv',sep=",",index_col=0)
df=df.fillna(0)
df=df.astype(int)
df.head()
# Out:
#              02-0047-01A-01R-1849-01+1  02-0047-01A-01R-1849-01+2  \
# item
# NC_000852.5                          0                          0
# NC_000871.1                          0                          0
# NC_000872.1                          0                          0
# NC_001350.1                          0                          0
# NC_001362.1                          0                          0
#
#              02-0055-01A-01R-1849-01+1  02-0055-01A-01R-1849-01+2  \
# item
# NC_000852.5                          0                          0
# NC_000871.1                          0                          0
# NC_000872.1                          0                          0
# NC_001350.1                          0                          0
# NC_001362.1                          0                          0
#
#              02-2483-01A-01R-1849-01+1  02-2483-01A-01R-1849-01+2  \
# item
# NC_000852.5                          0                          0
# NC_000871.1                          0                          0
# NC_000872.1                          0                          0
# NC_001350.1                          0                          0
# NC_001362.1                          0                          0
#
#              02-2485-01A-01R-1849-01+1  02-2485-01A-01R-1849-01+2  \
# item
# NC_000852.5                          0                          0
# NC_000871.1                          0                          0
# NC_000872.1                          0                          0
# NC_001350.1                          0                          0
# NC_001362.1                          0                          0
#
#              02-2486-01A-01R-1849-01+1  02-2486-01A-01R-1849-01+2  ...  \
# item                                                               ...
# NC_000852.5                          0                          0  ...
# NC_000871.1                          0                          0  ...
# NC_000872.1                          0                          0  ...
# NC_001350.1                          0                          0  ...
# NC_001362.1                          0                          0  ...
#
#              VW-A8FI-01A-11R-A36H-07+1  W9-A837-01A-11R-A36H-07+1  \
# item
# NC_000852.5                          0                          0
# NC_000871.1                          0                          0
# NC_000872.1                          0                          0
# NC_001350.1                          0                          0
# NC_001362.1                          0                          0
#
#              WH-A86K-01A-11R-A36H-07+1  WY-A858-01A-11R-A36H-07+1  \
# item
# NC_000852.5                          0                          0
# NC_000871.1                          0                          0
# NC_000872.1                          0                          0
# NC_001350.1                          0                          0
# NC_001362.1                          0                          0
#
#              WY-A859-01A-12R-A36H-07+1  WY-A85A-01A-21R-A36H-07+1  \
# item
# NC_000852.5                          0                          0
# NC_000871.1                          0                          0
# NC_000872.1                          0                          0
# NC_001350.1                          0                          0
# NC_001362.1                          0                          0
#
#              WY-A85B-01A-11R-A36H-07+1  WY-A85C-01A-11R-A36H-07+1  \
# item
# NC_000852.5                          0                          0
# NC_000871.1                          0                          0
# NC_000872.1                          0                          0
# NC_001350.1                          0                          0
# NC_001362.1                          0                          0
#
#              WY-A85D-01A-11R-A36H-07+1  WY-A85E-01A-11R-A36H-07+1
# item
# NC_000852.5                          0                          0
# NC_000871.1                          0                          0
# NC_000872.1                          0                          0
# NC_001350.1                          0                          0
# NC_001362.1                          0                          0
#
# [5 rows x 894 columns]

# %%
#viral_count=df.loc['Viral aligned pair Count'] #.astype(int)
#df=df.drop('Viral aligned pair Count')
#df.head()

# %%
#hg38_count=df.loc['HG38 aligned pair Count'] #.astype(int)
#df=df.drop('HG38 aligned pair Count')
#df.head()

# %%
df.shape
# Out:
# (478, 894)

# %%
default_max_rows=pd.get_option('display.max_rows')
pd.set_option('display.max_rows',1000)

#default_max_cols=pd.get_option('display.max_columns')
#pd.set_option('display.max_columns', 1000)

default_max_seq_items=pd.get_option('display.max_seq_items')
pd.set_option('display.max_seq_items', None)

# %%
#df.columns.str.split('-',expand=True).get_level_values(2)
#df.columns.str.match('^..-....-01')

# %%
pd.set_option('display.max_seq_items', default_max_seq_items)
pd.set_option('display.max_rows',default_max_rows)

# %%
df.shape
# Out:
# (478, 894)

# %% [markdown]
# ## Drop all but the 01's. There are some 02's and 11's.

# %%
#df.columns.str.split('-',expand=True).get_level_values(2).str.contains("01.")
#df.columns.str.match('^..-....-01')[0:9]

# %%
#df=df.iloc[:,df.columns.str.match('..-....-01.-...-....-..+.')]
df=df.iloc[:,df.columns.str.match('^..-....-01')]

# %%
df.shape
# Out:
# (478, 845)

# %%
df.columns
# Out:
# Index(['02-0047-01A-01R-1849-01+1', '02-0047-01A-01R-1849-01+2',
#        '02-0055-01A-01R-1849-01+1', '02-0055-01A-01R-1849-01+2',
#        '02-2483-01A-01R-1849-01+1', '02-2483-01A-01R-1849-01+2',
#        '02-2485-01A-01R-1849-01+1', '02-2485-01A-01R-1849-01+2',
#        '02-2486-01A-01R-1849-01+1', '02-2486-01A-01R-1849-01+2',
#        ...
#        'VW-A8FI-01A-11R-A36H-07+1', 'W9-A837-01A-11R-A36H-07+1',
#        'WH-A86K-01A-11R-A36H-07+1', 'WY-A858-01A-11R-A36H-07+1',
#        'WY-A859-01A-12R-A36H-07+1', 'WY-A85A-01A-21R-A36H-07+1',
#        'WY-A85B-01A-11R-A36H-07+1', 'WY-A85C-01A-11R-A36H-07+1',
#        'WY-A85D-01A-11R-A36H-07+1', 'WY-A85E-01A-11R-A36H-07+1'],
#       dtype='object', length=845)

# %%
max(df.sum(axis='columns'))
# Out:
# 274360

# %%
(df.sum(axis='columns')>1000)
# Out:
# item
# NC_000852.5    False
# NC_000871.1    False
# NC_000872.1    False
# NC_001350.1    False
# NC_001362.1    False
#                ...
# NC_055603.1    False
# NC_055645.1    False
# NC_055742.1    False
# NC_055794.1    False
# NC_055901.1    False
# Length: 478, dtype: bool

# %%
#tmp=df.iloc[(df.sum(axis='columns')>100).values,:]
#tmp.shape

# %% [markdown]
# ## Select only the common viruses ( sum > 1000 )

# %%
df=df.iloc[(df.sum(axis='columns')>1000).values,:]

# %%
df.shape
# Out:
# (9, 845)

# %%
df
# Out:
#              02-0047-01A-01R-1849-01+1  02-0047-01A-01R-1849-01+2  \
# item
# NC_001506.1                        113                         93
# NC_008094.1                          6                          4
# NC_009603.1                          0                          0
# NC_026927.1                          0                          0
# NC_030697.1                         10                          3
# NC_038858.1                          0                          0
# NC_048798.1                          7                          4
# NC_049392.1                          1                          0
# NC_053004.1                         71                         20
#
#              02-0055-01A-01R-1849-01+1  02-0055-01A-01R-1849-01+2  \
# item
# NC_001506.1                        356                        261
# NC_008094.1                          2                          2
# NC_009603.1                          0                          0
# NC_026927.1                          1                          0
# NC_030697.1                         80                         59
# NC_038858.1                          0                          0
# NC_048798.1                         12                          7
# NC_049392.1                          0                          0
# NC_053004.1                       3634                       1437
#
#              02-2483-01A-01R-1849-01+1  02-2483-01A-01R-1849-01+2  \
# item
# NC_001506.1                        201                        303
# NC_008094.1                          2                          4
# NC_009603.1                          0                          0
# NC_026927.1                          0                          2
# NC_030697.1                          4                         12
# NC_038858.1                          0                          0
# NC_048798.1                         12                         21
# NC_049392.1                          0                         13
# NC_053004.1                        151                        533
#
#              02-2485-01A-01R-1849-01+1  02-2485-01A-01R-1849-01+2  \
# item
# NC_001506.1                       1141                        596
# NC_008094.1                          5                          3
# NC_009603.1                          0                          0
# NC_026927.1                          0                          0
# NC_030697.1                          7                          0
# NC_038858.1                          1                          1
# NC_048798.1                         26                         15
# NC_049392.1                         14                          0
# NC_053004.1                        246                         70
#
#              02-2486-01A-01R-1849-01+1  02-2486-01A-01R-1849-01+2  ...  \
# item                                                               ...
# NC_001506.1                        110                        146  ...
# NC_008094.1                          5                          6  ...
# NC_009603.1                          0                          0  ...
# NC_026927.1                          0                          0  ...
# NC_030697.1                          3                         32  ...
# NC_038858.1                          0                          0  ...
# NC_048798.1                          7                         14  ...
# NC_049392.1                          1                        115  ...
# NC_053004.1                        224                        786  ...
#
#              VW-A8FI-01A-11R-A36H-07+1  W9-A837-01A-11R-A36H-07+1  \
# item
# NC_001506.1                        154                        100
# NC_008094.1                          0                          0
# NC_009603.1                          4                          5
# NC_026927.1                          1                          8
# NC_030697.1                          0                          0
# NC_038858.1                         54                         32
# NC_048798.1                          0                          0
# NC_049392.1                          0                          0
# NC_053004.1                          0                          0
#
#              WH-A86K-01A-11R-A36H-07+1  WY-A858-01A-11R-A36H-07+1  \
# item
# NC_001506.1                          4                        102
# NC_008094.1                          3                          2
# NC_009603.1                          1                          3
# NC_026927.1                          1                          8
# NC_030697.1                          0                          0
# NC_038858.1                          1                         42
# NC_048798.1                          0                          0
# NC_049392.1                          0                          0
# NC_053004.1                          0                          0
#
#              WY-A859-01A-12R-A36H-07+1  WY-A85A-01A-21R-A36H-07+1  \
# item
# NC_001506.1                         58                         42
# NC_008094.1                          5                          2
# NC_009603.1                          3                          1
# NC_026927.1                         13                          5
# NC_030697.1                          0                          0
# NC_038858.1                         32                         29
# NC_048798.1                          0                          0
# NC_049392.1                          0                          0
# NC_053004.1                          0                          0
#
#              WY-A85B-01A-11R-A36H-07+1  WY-A85C-01A-11R-A36H-07+1  \
# item
# NC_001506.1                        150                        210
# NC_008094.1                          1                          2
# NC_009603.1                          0                          1
# NC_026927.1                          3                          7
# NC_030697.1                          0                          0
# NC_038858.1                         58                         83
# NC_048798.1                          0                          0
# NC_049392.1                          0                          0
# NC_053004.1                          0                          0
#
#              WY-A85D-01A-11R-A36H-07+1  WY-A85E-01A-11R-A36H-07+1
# item
# NC_001506.1                         33                         51
# NC_008094.1                          1                          0
# NC_009603.1                          5                          5
# NC_026927.1                          3                          7
# NC_030697.1                          0                          0
# NC_038858.1                         14                         16
# NC_048798.1                          0                          0
# NC_049392.1                          0                          0
# NC_053004.1                          0                          0
#
# [9 rows x 845 columns]

# %%
ref=pd.read_csv('viral.csv',sep=',',index_col=0,header=None)
ref.index.name=None
ref
# Out:
#                                                              1
# AC_000001.1                 Ovine_adenovirus_A_complete_genome
# AC_000002.1                Bovine_adenovirus_B_complete_genome
# AC_000003.1                Canine_adenovirus_1_complete_genome
# AC_000004.1                  Duck_adenovirus_A_complete_genome
# AC_000005.1             Human_mastadenovirus_A_complete_genome
# ...                                                        ...
# NC_055918.1  Mycobacterium_phage_OhShagHennessy_complete_ge...
# NC_055919.1      Klebsiella_phage_vB_KpnP_P184_complete_genome
# NC_055920.1               Gordonia_phage_Phlop_complete_genome
# NC_055921.1       Salmonella_phage_vB_SalP_TR2_complete_genome
# NC_056724.1     Lactococcus_lactis_phage_BK5-T_complete_genome
#
# [14721 rows x 1 columns]

# %%
df.sum(axis='columns').to_frame().join(ref,how='left').sort_values(0)
# Out:
#                   0                                                  1
# item
# NC_009603.1    1221          Microbacterium_phage_Min1_complete_genome
# NC_008094.1    1733                  Y73_sarcoma_virus_complete_genome
# NC_049392.1    2039  Escherichia_phage_ESSI2_ev239_genome_assembly_...
# NC_048798.1    2855             Klebsiella_phage_Marfa_complete_genome
# NC_026927.1    3476  Synechococcus_phage_ACG-2014f_isolate_Syn7803C...
# NC_030697.1    4997  Picornavirales_Bu-3_gene_for_polyprotein_compl...
# NC_038858.1   19714  FBR_murine_osteosarcoma_complete_proviral_sequ...
# NC_001506.1  106306          Murine_osteosarcoma_virus_complete_genome
# NC_053004.1  274360              Salmonella_phage_TS13_complete_genome
