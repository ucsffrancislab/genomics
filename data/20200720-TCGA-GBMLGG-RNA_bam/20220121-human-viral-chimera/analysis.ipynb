# %%
import pandas as pd
pd.__version__
# Out:
# '1.3.5'

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.4.2'

# %%
#import matplotlib.pyplot as plt

# %%
# Adjust plot size
#options(repr.plot.width=16, repr.plot.height=6)

# For some reason, if this is in the same cell as the import command, it doesn't work.
#plt.rcParams["figure.figsize"] = [18.0,8.0]

# %%
import seaborn as sns
sns.__version__
# Out:
# '0.11.2'

# %%
df = pd.read_csv('merged.csv',sep=",",index_col=0)
df=df.fillna(0)
df=df.astype(int)
df.head()
# Out:
#              02-0047-01A-01R-1849-01+1  02-0047-01A-01R-1849-01+2  \
# item
# AC_000007.1                          0                          0
# AC_000008.1                          0                          0
# NC_000852.5                          0                          0
# NC_000871.1                          0                          0
# NC_000872.1                          0                          0
#
#              02-0055-01A-01R-1849-01+1  02-0055-01A-01R-1849-01+2  \
# item
# AC_000007.1                          0                          0
# AC_000008.1                          0                          0
# NC_000852.5                          0                          0
# NC_000871.1                          0                          0
# NC_000872.1                          0                          0
#
#              02-2483-01A-01R-1849-01+1  02-2483-01A-01R-1849-01+2  \
# item
# AC_000007.1                          0                          0
# AC_000008.1                          0                          0
# NC_000852.5                          0                          0
# NC_000871.1                          0                          0
# NC_000872.1                          0                          0
#
#              02-2485-01A-01R-1849-01+1  02-2485-01A-01R-1849-01+2  \
# item
# AC_000007.1                          0                          0
# AC_000008.1                          0                          0
# NC_000852.5                          0                          0
# NC_000871.1                          0                          0
# NC_000872.1                          0                          0
#
#              02-2486-01A-01R-1849-01+1  02-2486-01A-01R-1849-01+2  ...  \
# item                                                               ...
# AC_000007.1                          0                          0  ...
# AC_000008.1                          0                          0  ...
# NC_000852.5                          0                          0  ...
# NC_000871.1                          0                          0  ...
# NC_000872.1                          0                          0  ...
#
#              VW-A8FI-01A-11R-A36H-07+1  W9-A837-01A-11R-A36H-07+1  \
# item
# AC_000007.1                          0                          0
# AC_000008.1                          0                          0
# NC_000852.5                          0                          0
# NC_000871.1                          0                          0
# NC_000872.1                          0                          0
#
#              WH-A86K-01A-11R-A36H-07+1  WY-A858-01A-11R-A36H-07+1  \
# item
# AC_000007.1                          0                          0
# AC_000008.1                          0                          0
# NC_000852.5                          0                          0
# NC_000871.1                          0                          0
# NC_000872.1                          0                          0
#
#              WY-A859-01A-12R-A36H-07+1  WY-A85A-01A-21R-A36H-07+1  \
# item
# AC_000007.1                          0                          0
# AC_000008.1                          0                          0
# NC_000852.5                          0                          0
# NC_000871.1                          0                          0
# NC_000872.1                          0                          0
#
#              WY-A85B-01A-11R-A36H-07+1  WY-A85C-01A-11R-A36H-07+1  \
# item
# AC_000007.1                          0                          0
# AC_000008.1                          0                          0
# NC_000852.5                          0                          0
# NC_000871.1                          0                          0
# NC_000872.1                          0                          0
#
#              WY-A85D-01A-11R-A36H-07+1  WY-A85E-01A-11R-A36H-07+1
# item
# AC_000007.1                          0                          0
# AC_000008.1                          0                          0
# NC_000852.5                          0                          0
# NC_000871.1                          0                          0
# NC_000872.1                          0                          0
#
# [5 rows x 895 columns]

# %%
#viral_count=df.loc['Viral aligned pair Count'] #.astype(int)
#df=df.drop('Viral aligned pair Count')
#df.head()

# %%
#hg38_count=df.loc['HG38 aligned pair Count'] #.astype(int)
#df=df.drop('HG38 aligned pair Count')
#df.head()

# %%
df.shape
# Out:
# (732, 895)

# %%
default_max_rows=pd.get_option('display.max_rows')
pd.set_option('display.max_rows',1000)

#default_max_cols=pd.get_option('display.max_columns')
#pd.set_option('display.max_columns', 1000)

default_max_seq_items=pd.get_option('display.max_seq_items')
pd.set_option('display.max_seq_items', None)

# %%
#df.columns.str.split('-',expand=True).get_level_values(2)
#df.columns.str.match('^..-....-01')

# %%
pd.set_option('display.max_seq_items', default_max_seq_items)
pd.set_option('display.max_rows',default_max_rows)

# %%
df.shape
# Out:
# (732, 895)

# %% [markdown]
# ## Drop all but the 01's. There are some 02's and 11's.

# %%
#df.columns.str.split('-',expand=True).get_level_values(2).str.contains("01.")
#df.columns.str.match('^..-....-01')[0:9]

# %%
#df=df.iloc[:,df.columns.str.match('..-....-01.-...-....-..+.')]
df=df.iloc[:,df.columns.str.match('^..-....-01')]

# %%
df.shape
# Out:
# (732, 846)

# %%
df.columns
# Out:
# Index(['02-0047-01A-01R-1849-01+1', '02-0047-01A-01R-1849-01+2',
#        '02-0055-01A-01R-1849-01+1', '02-0055-01A-01R-1849-01+2',
#        '02-2483-01A-01R-1849-01+1', '02-2483-01A-01R-1849-01+2',
#        '02-2485-01A-01R-1849-01+1', '02-2485-01A-01R-1849-01+2',
#        '02-2486-01A-01R-1849-01+1', '02-2486-01A-01R-1849-01+2',
#        ...
#        'VW-A8FI-01A-11R-A36H-07+1', 'W9-A837-01A-11R-A36H-07+1',
#        'WH-A86K-01A-11R-A36H-07+1', 'WY-A858-01A-11R-A36H-07+1',
#        'WY-A859-01A-12R-A36H-07+1', 'WY-A85A-01A-21R-A36H-07+1',
#        'WY-A85B-01A-11R-A36H-07+1', 'WY-A85C-01A-11R-A36H-07+1',
#        'WY-A85D-01A-11R-A36H-07+1', 'WY-A85E-01A-11R-A36H-07+1'],
#       dtype='object', length=846)

# %%
max(df.sum(axis='columns'))
# Out:
# 298603

# %%
(df.sum(axis='columns')>1000)
# Out:
# item
# AC_000007.1    False
# AC_000008.1    False
# NC_000852.5    False
# NC_000871.1    False
# NC_000872.1    False
#                ...
# NC_055772.1    False
# NC_055789.1    False
# NC_055794.1    False
# NC_055833.1    False
# NC_055901.1    False
# Length: 732, dtype: bool

# %%
#tmp=df.iloc[(df.sum(axis='columns')>100).values,:]
#tmp.shape

# %% [markdown]
# ## Select only the common viruses ( sum > 1000 )

# %%
df=df.iloc[(df.sum(axis='columns')>1000).values,:]

# %%
df.shape
# Out:
# (15, 846)

# %%
df
# Out:
#              02-0047-01A-01R-1849-01+1  02-0047-01A-01R-1849-01+2  \
# item
# NC_001479.1                          4                          1
# NC_001506.1                         36                         30
# NC_008094.1                          2                          2
# NC_009603.1                          0                          0
# NC_026927.1                          0                          0
# NC_030697.1                         13                          5
# NC_038858.1                         23                         19
# NC_043054.1                         39                          8
# NC_048651.1                          0                          0
# NC_048798.1                          7                          4
# NC_049392.1                          1                          0
# NC_049948.1                          4                          0
# NC_053004.1                         70                         19
# NC_054919.1                        139                         73
# NC_054922.1                        809                        381
#
#              02-0055-01A-01R-1849-01+1  02-0055-01A-01R-1849-01+2  \
# item
# NC_001479.1                         95                         89
# NC_001506.1                         92                         78
# NC_008094.1                          2                          2
# NC_009603.1                          0                          0
# NC_026927.1                          1                          0
# NC_030697.1                         81                         59
# NC_038858.1                         94                         83
# NC_043054.1                        142                         99
# NC_048651.1                          7                          7
# NC_048798.1                         11                          6
# NC_049392.1                          0                          0
# NC_049948.1                         23                          0
# NC_053004.1                       3637                       1440
# NC_054919.1                        166                         84
# NC_054922.1                        915                        525
#
#              02-2483-01A-01R-1849-01+1  02-2483-01A-01R-1849-01+2  \
# item
# NC_001479.1                          3                          4
# NC_001506.1                         66                         89
# NC_008094.1                          2                          3
# NC_009603.1                          0                          0
# NC_026927.1                          0                          2
# NC_030697.1                          4                         13
# NC_038858.1                         57                         76
# NC_043054.1                          1                          8
# NC_048651.1                          0                          7
# NC_048798.1                         11                         20
# NC_049392.1                          0                          5
# NC_049948.1                          0                         28
# NC_053004.1                        153                        538
# NC_054919.1                        143                        266
# NC_054922.1                       1254                       2218
#
#              02-2485-01A-01R-1849-01+1  02-2485-01A-01R-1849-01+2  \
# item
# NC_001479.1                          3                          1
# NC_001506.1                        312                        201
# NC_008094.1                          1                          1
# NC_009603.1                          0                          0
# NC_026927.1                          0                          0
# NC_030697.1                          8                          1
# NC_038858.1                        327                        214
# NC_043054.1                         19                          3
# NC_048651.1                          1                          0
# NC_048798.1                         23                         12
# NC_049392.1                         10                          0
# NC_049948.1                         24                          0
# NC_053004.1                        247                         71
# NC_054919.1                        260                        129
# NC_054922.1                       1689                        923
#
#              02-2486-01A-01R-1849-01+1  02-2486-01A-01R-1849-01+2  ...  \
# item                                                               ...
# NC_001479.1                          1                          8  ...
# NC_001506.1                         37                         41  ...
# NC_008094.1                          3                          3  ...
# NC_009603.1                          0                          0  ...
# NC_026927.1                          0                          0  ...
# NC_030697.1                          3                         32  ...
# NC_038858.1                         32                         37  ...
# NC_043054.1                          3                         15  ...
# NC_048651.1                          0                         12  ...
# NC_048798.1                          7                         14  ...
# NC_049392.1                          1                        118  ...
# NC_049948.1                          0                         50  ...
# NC_053004.1                        233                        798  ...
# NC_054919.1                        120                        211  ...
# NC_054922.1                       1005                       1791  ...
#
#              VW-A8FI-01A-11R-A36H-07+1  W9-A837-01A-11R-A36H-07+1  \
# item
# NC_001479.1                          1                          0
# NC_001506.1                         75                         42
# NC_008094.1                          0                          0
# NC_009603.1                          4                          5
# NC_026927.1                          1                          8
# NC_030697.1                          0                          0
# NC_038858.1                         83                         60
# NC_043054.1                          6                          3
# NC_048651.1                          0                          0
# NC_048798.1                          0                          0
# NC_049392.1                          0                          0
# NC_049948.1                          0                          0
# NC_053004.1                          0                          0
# NC_054919.1                          0                          0
# NC_054922.1                          0                          0
#
#              WH-A86K-01A-11R-A36H-07+1  WY-A858-01A-11R-A36H-07+1  \
# item
# NC_001479.1                          0                          0
# NC_001506.1                          3                         52
# NC_008094.1                          3                          1
# NC_009603.1                          1                          3
# NC_026927.1                          1                          8
# NC_030697.1                          0                          0
# NC_038858.1                          2                         56
# NC_043054.1                          0                          2
# NC_048651.1                          0                          0
# NC_048798.1                          0                          0
# NC_049392.1                          0                          0
# NC_049948.1                          0                          0
# NC_053004.1                          0                          0
# NC_054919.1                          0                          0
# NC_054922.1                          0                          0
#
#              WY-A859-01A-12R-A36H-07+1  WY-A85A-01A-21R-A36H-07+1  \
# item
# NC_001479.1                          0                          0
# NC_001506.1                         38                         33
# NC_008094.1                          5                          2
# NC_009603.1                          3                          1
# NC_026927.1                         13                          5
# NC_030697.1                          0                          0
# NC_038858.1                         30                         27
# NC_043054.1                          0                          0
# NC_048651.1                          0                          0
# NC_048798.1                          0                          0
# NC_049392.1                          0                          0
# NC_049948.1                          0                          0
# NC_053004.1                          0                          0
# NC_054919.1                          0                          0
# NC_054922.1                          0                          0
#
#              WY-A85B-01A-11R-A36H-07+1  WY-A85C-01A-11R-A36H-07+1  \
# item
# NC_001479.1                          0                          0
# NC_001506.1                         72                        121
# NC_008094.1                          1                          1
# NC_009603.1                          0                          1
# NC_026927.1                          3                          7
# NC_030697.1                          0                          0
# NC_038858.1                         81                        104
# NC_043054.1                          2                          1
# NC_048651.1                          0                          0
# NC_048798.1                          0                          0
# NC_049392.1                          0                          0
# NC_049948.1                          0                          0
# NC_053004.1                          0                          0
# NC_054919.1                          0                          0
# NC_054922.1                          0                          0
#
#              WY-A85D-01A-11R-A36H-07+1  WY-A85E-01A-11R-A36H-07+1
# item
# NC_001479.1                          0                          0
# NC_001506.1                         10                         26
# NC_008094.1                          1                          0
# NC_009603.1                          5                          5
# NC_026927.1                          3                          7
# NC_030697.1                          0                          0
# NC_038858.1                         24                         27
# NC_043054.1                          2                          1
# NC_048651.1                          0                          0
# NC_048798.1                          0                          0
# NC_049392.1                          0                          0
# NC_049948.1                          0                          0
# NC_053004.1                          0                          0
# NC_054919.1                          0                          0
# NC_054922.1                          0                          0
#
# [15 rows x 846 columns]

# %%
ref=pd.read_csv('viral.csv',sep=',',index_col=0,header=None)
ref.index.name=None
ref
# Out:
#                                                              1
# AC_000001.1                 Ovine_adenovirus_A_complete_genome
# AC_000002.1                Bovine_adenovirus_B_complete_genome
# AC_000003.1                Canine_adenovirus_1_complete_genome
# AC_000004.1                  Duck_adenovirus_A_complete_genome
# AC_000005.1             Human_mastadenovirus_A_complete_genome
# ...                                                        ...
# NC_055918.1  Mycobacterium_phage_OhShagHennessy_complete_ge...
# NC_055919.1      Klebsiella_phage_vB_KpnP_P184_complete_genome
# NC_055920.1               Gordonia_phage_Phlop_complete_genome
# NC_055921.1       Salmonella_phage_vB_SalP_TR2_complete_genome
# NC_056724.1     Lactococcus_lactis_phage_BK5-T_complete_genome
#
# [14721 rows x 1 columns]

# %%
df.sum(axis='columns').to_frame().join(ref,how='left').sort_values(0)
# Out:
#                   0                                                  1
# item
# NC_009603.1    1221          Microbacterium_phage_Min1_complete_genome
# NC_008094.1    1233                  Y73_sarcoma_virus_complete_genome
# NC_049392.1    1589  Escherichia_phage_ESSI2_ev239_genome_assembly_...
# NC_001479.1    1854         Encephalomyocarditis_virus_complete_genome
# NC_048651.1    1959            Aeribacillus_phage_AP45_complete_genome
# NC_048798.1    2710             Klebsiella_phage_Marfa_complete_genome
# NC_026927.1    3476  Synechococcus_phage_ACG-2014f_isolate_Syn7803C...
# NC_049948.1    5280  Escherichia_phage_Lambda_ev017_genome_assembly...
# NC_030697.1    5723  Picornavirales_Bu-3_gene_for_polyprotein_compl...
# NC_043054.1    8809  Bubaline_alphaherpesvirus_1_strain_b6_complete...
# NC_054919.1   40273    Escherichia_phage_vB_EcoM_G4507_complete_genome
# NC_001506.1   44440          Murine_osteosarcoma_virus_complete_genome
# NC_038858.1   45165  FBR_murine_osteosarcoma_complete_proviral_sequ...
# NC_053004.1  279465              Salmonella_phage_TS13_complete_genome
# NC_054922.1  298603  Escherichia_phage_vB_EcoM_KAW1E185_complete_ge...
